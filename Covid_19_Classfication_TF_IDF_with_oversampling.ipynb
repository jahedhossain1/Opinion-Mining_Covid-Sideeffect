# %% [markdown]
# # **Import All File**

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# # **Import Dataset**

# %%
df=pd.read_excel('Covid_19_dataset_with_preprocessing_3700_data_2.xlsx')
df.head()
# Out:
#                                              opinion  Category
# 0  টিকায় সুরক্ষ দরক নাই বেক্সিমকোর জয়েন্ট ভেঞ্চ...         2
# 1       মত মৃত্যুর ভয়ে ঘরে বসে থাকা সামর্থ্য সব নেই         1
# 2                               সৈকত বন্ধ দেয়া সরকার         0
# 3  বর্তমানে করোনা মহামারি প্রকৃতির পক্ষথে গজব তার...         0
# 4  এরপর একটু সচেতনতা বৃদ্ধি হয় তাইলে কুকুর কামড়...         2

# %% [markdown]
# #**Define Dataset length**

# %%
len(df)
# Out:
# 3700

# %% [markdown]
# # **Check If there any null Value**

# %%
df.isnull().sum()
# Out:
# opinion     1
# Category    0
# dtype: int64

# %%
df=df.dropna()

# %%
df.Label = df.Category.astype(int)
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
df.isnull().sum()
# Out:
# opinion     0
# Category    0
# dtype: int64

# %% [markdown]
# # **Totall Data in every group**

# %%
df.groupby('Category').size().reset_index(name='counts')
# Out:
#    Category  counts
# 0         0    1547
# 1         1     971
# 2         2    1181

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (18, 7)
visitor = df
size = visitor['Category'].value_counts()
colors = ['lightskyblue', 'c', 'orange']
labels =  "Analytical", "Angry", "Depressed"
explode = [0.0, 0.0, 0.0]
plt.subplot(1, 1, 1)
plt.pie(size, colors = colors, labels = labels, explode = explode, shadow = True, autopct = '%.2f%%')
plt.title('Category', fontsize = 30)
plt.axis('off')
plt.legend()
plt.savefig('Category_with_imbalanced_dataset.png')

# %% [markdown]
# #**Balancing Dataset:**

# %% [markdown]
# **Resample:**

# %%
from sklearn.utils import resample

# %%
# Separate majority and minority classes
df_majority = df[df.Label==0]
df_majority1 = df[df.Label==1]
#df_minority = df[df.Label==0]
df_minority2 = df[df.Label==2]
#df_minority2 = df[df.Label==4]

# %%
# Separate majority and minority classes
#df_majority = df[df.Label==1]
#df_majority1 = df[df.Label==2]
#df_minority = df[df.Label==0]
#df_minority2 = df[df.Label==3]
#df_minority2 = df[df.Label==4]

# %%
# Upsample minority class
#df_minority_upsampled = resample(df_minority2, 
                                 #replace=True,     # sample with replacement
                                # n_samples=1000,    # to match majority class
                                 #random_state=123) # reproducible results
#df_minority_upsampled1 = resample(df_minority1, 
                                 #replace=True,     # sample with replacement
                                # n_samples=1131,    # to match majority class
                                 #random_state=123)
df_minority_upsampled2 = resample(df_majority1, 
                                 replace=True,     # sample with replacement
                                 n_samples=1547,    # to match majority class
                                 random_state=342)
df_minority_upsampled3 = resample(df_majority, 
                                 replace=True,     # sample with replacement
                                 n_samples=1547,    # to match majority class
                                 random_state=342)
df_minority_upsampled4 = resample(df_minority2, 
                                 replace=True,     # sample with replacement
                                 n_samples=1547,    # to match majority class
                                 random_state=342)

# %%
# Combine minority class with upsampled majority class
df_upsampled = pd.concat([df_minority_upsampled4,df_minority_upsampled3,df_minority_upsampled2])

# %%
df_upsampled.groupby('Category').size().reset_index(name='counts')
# Out:
#    Category  counts
# 0         0    1547
# 1         1    1547
# 2         2    1547

# %%
df_upsampled.head()
# Out:
#                                                 opinion  Category
# 44    নিকা লোক নিজে সুরক্ষিত ভাব অসুরক্ষিত চলাফে সমস...         2
# 612                                    এরে জুতা খাওয়ানো         2
# 398                           ওরে বাটপ দুনিয়া করোনা নাই         2
# 3355          মু‌খে আ‌সে ব‌ টেস্ট বেশী ক্ষমতা হই‌লো না         2
# 599   পৃথিবীর সবচ অশিক্ষিত মুর্খ বর্বর জাতী ইন্ডিয়ান রা         2

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (18, 7)
visitor = df_upsampled
size = visitor['Category'].value_counts()
colors = ['lightskyblue', 'c', 'orange']
labels =  "Analytical", " Angry ", "Depressed"
explode = [0.0, 0.0, 0.0]
plt.subplot(1, 1, 1)
plt.pie(size, colors = colors, labels = labels, explode = explode, shadow = True, autopct = '%.2f%%')
plt.title('Category', fontsize = 20)
plt.axis('off')
plt.legend()
plt.savefig('Category_with_balanced_dataset.png')

# %%
df_upsampled.shape
# Out:
# (4641, 2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
# import some data to play with
#df=pd.read_excel('Covid_19_dataset_with_preprocessing_3700_data.xlsx')
X = df_upsampled.iloc[:,:-1]
y = df_upsampled.iloc[:,-1]
class_names = y
labels, counts = np.unique(y, return_counts=True)
plt.bar(labels, counts, align='center')
plt.gca().set_xticks(labels)
plt.show()
plt.savefig('balanced_dataset.png')

# %%
#df_upsampled.to_pickle('/content/drive/MyDrive/Dataset/dataset4_with_balancing2.pkl')

# %%
corpus = []
for index,value in df_upsampled.iterrows():
    text = str(value['opinion'])
    corpus.append(text)

# %%
corpus
# Out:
# ['নিকা লোক নিজে সুরক্ষিত ভাব অসুরক্ষিত চলাফে সমস্যা দোষ',
#  'এরে জুতা খাওয়ানো',
#  'ওরে বাটপ দুনিয়া করোনা নাই',
#  'মু\u200cখে আ\u200cসে ব\u200c টেস্ট বেশী ক্ষমতা হই\u200cলো না',
#  'পৃথিবীর সবচ অশিক্ষিত মুর্খ বর্বর জাতী ইন্ডিয়ান রা',
#  'কেই বলে সাধারন মানুষ মার না',
#  'ব্রাজিল স্বাস্থ্য সেবা ভেঙ্গে পড় রিপোর্ট করছেনঅ অামা স্বাস্থ্য সেবা খুব শক্ত অবস্থানে অাছ নাযত হলুদ সাংবাদিকতা অাপনা করছ',
#  'ভারত ভ্যাকসিন না পারেতাহলে ক্ষতিপূরণ সহ টাকা ফিরত',
#  'সরকার কথায় পুলিশ শুধু খাট খাওয়া রিকশা ওয়ালা লকডাউন পিটুনি রিকশা ভাঙ অকথ্য ভাষায় গালাগা পুলিশ নৈতিক অবস্থান',
#  'গবেষণ নামে ফান্ড হাতানোর নতুন কৌসলদু মাস গবেষণা বল বল বাংলাদেশের মরে ছাফতখন বল করোনা দুর্বল পড়েছেএর আগ রোগ বিস্তার খমতা নেইআসলে করোনা ভাইরাসে সংক্রামিত হব মত লোক বাচ না বাংলাদেশেএ কথ ফায়দা লুট কুলাঙ্গাররাযাহা পার নগদ কর পর চিন্তা পরেরাশিয়ার মত রাস্তায় বাঘ ছাড় বুঝানোর সময় নাই বাহিরে বের বাঘে খায় ফলবেতখন ঘরে সোজা উপায়',
#  'স্বাস্থ্য খাত দুর্নীতির মহাসাগরে পতিত',
#  'শিক্ষা মন্ত্রণালয় ব্যর্থতা এভাবে সরকার ব্যর্থতায় পর্যবসিত হয়',
#  'পুলিশ আচরণ পুলিশ প্রতি ঘৃণা জন্ম নেয়',
#  'ঈদের নামাজ একসঙ্গে পড়লে করনা ধর সম্ভবনা মার্কেট বাজরে ঘুরলে করনা ধরবেনাআল্লাহ বেশি গযব দিবে নব্য ফেরাউন দের কৃতকর্ম',
#  'অসচেতন জাতির ডান্ডা ছাড়া উপায় নাই অসভ্য জাতি বাঁশ সোজা',
#  'মারা ফন্ধি',
#  'এভাবে অটো পাস শিক্ষাব্যবস্থা ভবিষ্যৎ প্রজন্ম বারোটা বাজবে',
#  'এই সরকার দূর্বল ব্যাবস্থাপনা দ্বায়ী',
#  'ভারত বাংলাদেশ ঢুকলে তাদের বছর জেল দেয়া',
#  'প্রবাসী খেলা বন্ধ',
#  'চুক্তি অনুযায়ী টিকা না দেয়ায় ভারত বিরুদ্ধে মামলা',
#  'এইসব ক্রস ফায়া দেয় না কেনো',
#  'খোলা গন পরিবন বন্ধ এই ধরন ফাজলামি',
#  'বাড়ীওয় বিরুদ্ধে আইনানুগ ব্যবস্থা',
#  'মাক্স না পড়লে শাস্তি দেয়া অযথা করোনা টেস্ট সরক অর্থ নষ্ট বুঝি না',
#  'মিথ্যা খবর',
#  'কোথায় সমালোচনা কারি নাম আমানুষ গুলা তারা করেছিলো বাংল ভালো চায়না এদেশের চির শত্রু',
#  'ডাক্ত সাহেব আপনা আপনা ছাড়া গতি নেই ঠিক আমা মানি আপনা জান আপনা গতি নেই আমা বিদ্যুৎ পানি গ্যাস টেলিফোন ধরন কর্ম জরিত আপনা সেবা বন্ধ আপনা অবস্থা ভাব দেখুন সব অবস্থানে নিজ দায়িত্ব পালন',
#  'নিজ টীকা উৎপাদন চিন্তা নেই ব্যবসা ব্যবসা',
#  'অনেক ভালো সারর্কাস দেখছিআর কত',
#  'রোগি আহ্বান জানাবো হাসপাতালে ভাংচুর প্রয়োজনে আগুন লাগা দরক ভিআইপিরা পাবে বাকি জনগন না',
#  'ভূয়া ব্যবস্হা নেয়া হয়নি',
#  'লক ডাউন হয় গাড়ি যেহেতু চলবে দিনমজুর শ্রমিক বসা হয়',
#  'ভারত ভ্যাকসিন না পারেতাহলে ক্ষতিপূরণ সহ টাকা ফিরত',
#  'টিকায় সুরক্ষ দরক নাই বেক্সিমকোর জয়েন্ট ভেঞ্চারে গণভবন ব্যাবসা সুরক্ষিত হয় ভাল',
#  'শালা পুতেরা খোলা সুধু গন পরিবহন মাথা ব্যাথা লাথি মারি ওগো পাছায়',
#  'পদত্যাগ',
#  'সরকারি র দালাল ঝমুনা',
#  'টাকা ইনকাম ধান্দা ঔষধ করোনা না তাইলে মাকস ঔষধ ব্যবহ করেনা আসবে না',
#  'বেপরোয়া রাস্তায় নামলে বোঝা নিয়ম ভাঙা তীব্র প্রতিযোগিতা করোনাকালীন পরিস্থিতি স্বাস্থ্য বিধি না মানা চূড়ান্ত অনীহা',
#  'লকডাউন জরুরি সচেতনতা সরক লকডাউন চালিয়ে সাধারণ লকডাউন অমান্য',
#  'স্বাস্থ্য মন্ত্রী জাহিদ মালেকের পদত্যাগ দাবি কর বইমেলা সহ আয়োজন বন্ধ জোর দাবি কর',
#  'বড় কোম্পানি অবশ্য এসব নাতা মাঠ পযার্য় সকল নাও করোনা পারবেনা মাস শাষ কোম্পানি বেতন দেয়তা এসকল কোম্পানির মালিক পা চাটা কুকু মিলে সাধারণ অল্প বেতন মানুষ বাধ্য দেশ করোন বিস্ত ঘট সাহায্য টিভি বার বার না বলেপারলে সকল শিক্ষত বড় দের থামা নাহলে মহামারি দেশ জাতী বাচানো যাবেনা',
#  'বাংলাদেশের কোথা করোনা নাই ভন্ডামী',
#  'স্বাস্থ্যবিধি মানা সরক জোরালো আইন',
#  'সরকার উদাসীনতা বর্বর জনগন জনগন',
#  'খাইতে পায় না বাল লকডাউন',
#  'অক্সিজেনের ব্যবহ নেইসেখানে বল সামাল পারছেনাসব মিথ্য অযুহাততা অন্যভাবে সিন্ডিকেড করত',
#  'এরে জুতা খাওয়ানো',
#  'এসব টাকা বরাদ্দ হয় শুধুমাত্র চুর মেম্ব চেয়ারম্যান এমপি মন্ত্রি জনগণ নয়',
#  'বাড় অসচেতনতা সিগারেট খাওয়াবাংগালী মরন ভয় নাবীর জাতিখয়রাতি',
#  'মৃত্যু র মামলা প্রয়োজন রাষ্ট্র র বিরুদ্ধে',
#  'সিঙ্গাপুরে বিশেষজ্ঞ দল বারে ফালতু বলেছিল করোনা ভাইরাস বাংলাদেশ মে মাস তারিখ কয় এখনো নাএখন বলে সংক্রমণ না ফালতু বানোয়াট খবর',
#  'অর্জন নোংড়া রাজনীতিরর দেশ বিরাট মাইলফলকদেশ বিদেশ বহু গবেষক দেশ উতসাহ পাবে',
#  'পুলিশ পুলিশ নাই বিনা ভোট অবৈধ সরকার লাঠিয়াল বাহিনী পরিণত হয় বিরুদ্ধে জনগণ ঐক্যবদ্ধ',
#  'কমেণ্ট লজ্জা লাগে',
#  'মরলে মর ভাংগা হাসপাতাল কিলিনিক মরে যাবকিনতু সবাইকে নিয়েভা দের জার করোন রুগি জড়ি ধরবে মক হাসি দিব',
#  'সার পৃথিবীর ভ্যাকসিন বাংলাদেশের ভ্যাকসিন',
#  'কসাইরা ভাল হওয় না নেশা সুদু টাকা সেবা না',
#  'এবারো অটোপাশ এভাবে ধংস',
#  'মরে শিক্ষা না',
#  'বাংলাদেশের সকল জেলাউপজেলা ইউনিয়ন পর্য সকল চেয়ারম্যান মেম্বার গোয়েন্দা নজরদারি রাখাহোক ত্রান চুরি না',
#  'অাল্লাহর গজব অাসবে বাংলাদেশের',
#  'কষ্ট লাঘব হলে এসব কঠোর বিধিনিষেধ নামে প্রহসন বন্ধ',
#  'সরক বেইমানি না কর টিকা অনেক বের যেতসরক খানে সার্থকতা চায় শান্তি কবে সরক চায় সার্থকতা পাবলিক চায় স্বাধীনতা',
#  'গণপরিবহন শ্রমিক ধান্দাবাজ তিন ডবল ভাড়া বেশি ঝামেলা পাকাবে',
#  'ভুয়া মারা বানাই',
#  'অবস্থা স্থানে দোকান বন্ধ লকডাউন না যতদিন সচেতনতা আন না',
#  'লকডাউন চলবে না বাংলাদেশ',
#  'লকডাউন চোদা পাট ভাত নেই চিকিৎসা নেই তোমা মত কোটি টাকা লুট ঘর ভোরে খাবা কিনে বসে নেই',
#  'ভাগ্য ভালো ইউরোপ আমেরিকার অবস্থা নি হত বাঙালির লাশ কুকুরে খাইতো',
#  'এদেশের ভিতরে প্রকারে গেমজাম সৃষ্ মিডিয়া নামক দালাল',
#  'বাংলাদেশের অনেক রেকর্ড বাকি থাকলোভ পরিনতি',
#  'আদা পাগলা বালচাল শুুধু ইন্ডিয়াতেই পাওয়া নেতা ভাবতে অবাগ লাগে',
#  'গন পরিবহন চালু কেঊ বলে নাইপ্রাইভেট গাড়ি কেনো চালু হল সেটা চায়বন্ধ থাকলে বন্ধ',
#  'এইসব বোকালোক বোঝানো উলোবনে মূক্তা ছড়ানো কথা হাত আঙ্গুল সমান না সকল বিচ ক্ষমতা না এসকল নির্বোধ সমবেদনা ছাড়া নাই',
#  'টাকা ওপরে দাম কেঊ না কেনা ভালো ঊপকারিতা নয় বরং পার্শ্বপ্রতিক্রিয়া হিসাবে কিডনী ড্যামেজ সম্ভাবনা রয়',
#  'আজাইরা নিউজ ভিতি ছড়ানো',
#  'অনেক ভালো সারর্কাস দেখছিআর কত',
#  'অযতা ফালতু লকডাউন দেয়া হয়',
#  'কঠোরতা নয় অমানুষ পরিচয় দেয় পুলিশ',
#  'সচেতনতা বৃদ্ধি',
#  'স্বাস্থ্য বিধির প্রয়োজনে জরিমানা ডাবল মাক্স সহজ দ্রব্য জেল জরিম আইন',
#  'জনগন খাবারের ব্যবস্হা না লকডাউন মানে পাগলামী ছাড়া না',
#  'এতদিন করোনা না ইস্কুল খোল কথা বললে করোনা হয়ে এই নতুন নাটক',
#  'লকডাউন নামে সাধারন হয়রানী এই লকডাউন নয় গরীব মার ফন্দি',
#  'গন পরিবহন বন্ধ ছোট বহন ছাড় টাকা ভাড়া টাকা চার নেওয় জায়গায় হচ্চে বাংল নাম লক ডাউন অটো বা সিএনজি তার বাস উত্তম ছিলো দুরত্ব বজায় যাতায়াত যেত লক ডাউন শ্রেনীর লোক কোটিপতি শ্রেনী পথ ভিখারী',
#  'টিকা নেওয়া তিন জ্বরে ভুগা',
#  'জনগন জান ত্রান নিয়ে ভালো তামাশা কর সরক',
#  'সরকার আসকা পায় জানোয়',
#  'ফালতু মন্ত্রী',
#  'সরকারি র দালাল ঝমুনা',
#  'সংক্রমন না হওয় শতর্কবাণী বেপরোয়া দোষ সরক',
#  'মাস্ক না পরলে দুই চারটা লাঠিপে',
#  'ওমান দেশ আমা বাসায় রোমে কোওয়ারেন্টেন নিয়ম দিছ দেশ ধান্দা রাস্তা খুল',
#  'চীন বেশি বাড় গেছেচীন বিচ দরকারদেরি বড় ধরণ সমস্যা',
#  'শালা পুতেরা খোলা সুধু গন পরিবহন মাথা ব্যাথা লাথি মারি ওগো পাছায়',
#  'জুলুম বাসেএ লোক বাসে আসলে সামাজিক দূরত্ব বজায় থাক যাত্রি বাস চল',
#  'লকডাউন খুলে আক্রান্ত ব্যক্তির সংখ্যা বাড় যারফলে অর্থনীতির উন্নতি',
#  'সমবেদনা মীরজাফর নায়ক সাফল্য হাসি উড়া দিয়েছিল',
#  'নাটক পরিনতি খুব খারাপ',
#  'সরক নিয়ন্ত্রণ পার না লক ডাউন নেয় না জনগণ ভোগান্তি দেব অধিক নেই সরকার',
#  'হেত উন্নয়ন বিরুদ্ধে ষড়যন্ত্রকারী হেতের মরোনোত্তর ফাসি',
#  'একাত্তর মুর্দাবাদ বয়কট একাত্তর টিভি',
#  'ডাক্ত মাস ভ্যাকসিন বানিয়ে ফাল শুনি অনুমতি কেবল দিল ডাক্ত ফালতু বক',
#  'জনগন সরক লকডাউন বিরুদ্ধে বিক্ষোভ মিছিল উচিৎ না পরিণামে দেশ দুর্ভিক্ষে পতিত',
#  'হোটেল না থাকলে কারাগারে পাঠান',
#  'ওরে বাটপ দুনিয়া করোনা নাই',
#  'আস্ আস্ করোনা ভাইরাস ভিআইপি ভিভিআইপি সবাইকেই ধরবে মৃত্যুর প্রস্তুত থাকো',
#  'কত সহ্য সরকার পাগলামি',
#  'ভাই দেশীয় টিক অনূমোদন দিলে কুটি কুটি টাকা দুর্নীতির ইনকাম পারবেনা নাটক সাজানো অভিশপত জাতী',
#  'সচেতন হউন জনগণ হবেআপনা সামাজিক দূরত্ব মান চল কথা বলছ স্বাস্থ্য মন্ত্রী সামাজিক দূরত্ব বজায় না রাখ যারযার করছে…',
#  'মাঝে মাঝে চিন্তা পৃথিবী গাজা না থাক বলদা দের অবস্থা হইত গাজা জিন্দাবাদ বলদা জিন্দাবাদ শালা গাড়ল',
#  'অফ আদালত হাট বাজা বিভিন্ন অনুষ্ঠান মাহফিল রাজনৈতিক মিটিং মিছিল ভোট হয় করোনাকালিন সময় স্কুলকলেজ শিক্ষাক্ষা করোনা খায় ফেল এই নাটক ছাড়া না বলদা মার্কা শিক্ষামন্ত্রালয় কর্মচারী',
#  'চোর কমিশন গ্লোব টিক অনুমোদন টালবাহানা',
#  'টাটকা মিছা কথা শিক্ষা প্রতিষ্ঠান বন্ধ রাখা নাটক',
#  'বাপ জন্মে কোনদিন নাই হয় জন্ম প্রথম এইট আসলে যতদিন না ডাঙ্গা পুলিশ ধার জারি না ততদিন বাংলাদেশের মানুষ সুরক্ষিত না মত কারনে ঈদের বাংলাদেশের মানুষ দাফন জায়গা না',
#  'এক দম না দুই চুকরোনায় মারা গরমে দম বন্ধ মরি তোরা গুজব চড়ানো মার্কা নিউজ পারবি করোন মৃত সংখ্যা দাড়াল মাইবো গরমে তোরা বাহবা দিবি করোনারে',
#  'প্রতিদিন মর ঠিক না কখনো সোজা না',
#  'লকডাউন জোরদ',
#  'গরুর মুত',
#  'পরিবেশ পরিস্থিতি বিবেচনায় বাংলাদেশের চাইনিজ ভ্যাকসিন উৎকৃষ্ট ভ্যাক্সিন বাংলাদেশ আন প্রয়োজন ছিলনা করোনা রাজনীতি প্রতিফলন হিসাবে এসব ঘট',
#  'এত আরামে শিশু আকুতি কষ্টে গরীব বাচ্চা অবস্থা এসব পেইজে আসবে না খাবা নেই ঠিকম সরক কেড়ে নিয় শিক্ষা',
#  'গণপরিবহন চালু বাল লকডাউন ভোগান্তি ছাড়া না টাকা ভাড়া টাকা রিকশায় অফ',
#  'সৌদি মাএ হয়েছিল কত নিয়ম চালু করছেক কঠোর ব্যবস্থা নেওয়া হয় বাংলাদেশের হাজারো বেশি ব্যবস্থা নেই নমুনা সংগ্রহ বন্ধ না হয় অনেক কঠোর ব্যবস্থা নেওয়া',
#  'কিন্ত শৈরাচারি দল চাইবে তৈরি ভ্যাক্সিন লাথি মার ফাল তার বাপ বা তার স্বামীর ভ্যাক্সিন বাংলাদেশ মার্কেট পাওয়াতে',
#  'জনগণ ম্যান্ডেটবীহিন সরকার অদক্ষতা অদূরদর্শীতা অব্যাবস্হাপনা সিদ্ধান্তহীনতা সমম্বয়হীনতা উদাসীনতা অসচেতনতা অসততা লুকোচুরি তথ্য গোপন করোনা প্রতিরোধে নজির বীহিন ব্যর্থত কারণে চরম অনিশ্চয়তা ভয়াবহ মানবিক বিপর্যয় দারপ্রান্',
#  'খুলে দিলে গনপরিবহন দোষ করলো',
#  'দায় সাস্থ্যমন্ত্রী কারন মিথ্যা তথ্য জনগন সরক বিভ্রান্ত কর সময় সাস্থ্য মন্ত্রী সরান',
#  'চিকিৎসক অবহেল কারনে রোগীর অবস্থা',
#  'এসব বাল লকডাউন করোনা রোধ সম্ভব না',
#  'বাংগালির লকডাউন দরক নাই',
#  'পুলিশ পুলিশ নাই বিনা ভোট অবৈধ সরকার লাঠিয়াল বাহিনী পরিণত হয় বিরুদ্ধে জনগণ ঐক্যবদ্ধ',
#  'ভূয়া নিউজ ছড়িয়ে চলমান টিকা কার্যক্রম গতি হ্রাস না করব অনুরোধ কর বিবিসি বাংলা কতৃপক্ষ মানুষ উৎসাহ না পারলে নিরউৎসাহ না দয়াকরে',
#  'দূরপাল্ল বাস মালিক আনেদালন গাড়ি গণপরিবহন না গরীব শমিকল মারা পদিমা',
#  'দেশ ঠিক নাই দেশ কিস ভ্যাকসিন গরু ছাগল',
#  'যেই সার্জেনট প্রতিবন্ধী ওয়ালা ভাই মামলা আল্ল গজব পরুক',
#  'পাগল বানা ভারত কত ভাঙ্গাবে হাও টিকায় হইনা',
#  'করোনা হয়া উচিদভা কথা করোনায় ভয় আদালত বন্দ হাজা হাজা বিচ পায়ানাএ বলে আদাল আসলে করোনা বিচ অনলাইনে কেনো করোনা হোলহেএ ঠিক করেনা',
#  'লকডাউন দুর পাল্ল গনপরিবহন বাছা ট্র লঞ্চ মালিক শ্রমিক মারা পায়তা চল',
#  'ভারত ভিক্ষা বাংলাদেশ অক্সিজ উৎপাদন পারছেনা',
#  'খোদ গজব পরুক এসব পুলিশ গরিব পাট লাথি মারে',
#  'নিয়ম মারি',
#  'জনগন টিকা নেওয় উদ্ভুদ্ধ এটা গুড ফন্দি ফিকির আইডিয়া',
#  'কঠর রিক্সা দিনমজুর অসহায় সাধারন পাবলিক উপরধান্দা পুলিশ সেখানে',
#  'অাল্লাহর গজব অাসবে বাংলাদেশের',
#  'আসলে করন গজব আরেক গজব নাম আসবে বাংল মাটি গরিব গুল অধিক কাড় নেওয়',
#  'আপনা মত সাৎবাদিক আতংকিত',
#  'জনগণ অতিরিক্ত ভাড়া আদায় পাতানো ফাঁদ',
#  'খুলে দিলে গনপরিবহন দোষ করলো',
#  'দেশ গুণীর সমাদর নাইসে দেশ গুণী জন্মা নাআর হল চোর জাতী গুণী লোক কথা বুঝিনা',
#  'ওষুধ না বিভিন্ন ওষুধ কোম্পানি আলা ফেসবু স্ট্যাটাস দেয় বিরুদ্ধে ব্যবস্থা নেওয়া অন্যথায় অনেক ক্ষতিকর মুখে',
#  'শালা গ্লোব বায়োটেক অনুমতি দিচ্ছনা কারো আশায় বসে না টিক সহযোগিতা করছো না',
#  'বাংলাদেশ চল ফাঁকা বুলি বলদ জনতা ঘুম পাড়ানো মুলত প্রবাসী শ্রমিকেরা বিদেশ মহামারীর সময় মানবেতর জীবনযাপন',
#  'তাইলে এত টাকা টিকা এনে লাভ',
#  'ধরন লকডাউন প্রশাসন প্রতিরোধ এলাকায় মদ জুয় আসর বসা করোনা প্রতিরোধ নয়',
#  'নিয়ম না লকডাউন মারান মিয়া গরীব ঘরে আগ খাবর লগডাউন',
#  'চেয়ারে অযোগ্য লোক দাপট সেখানে প্রবাসী না লকডাউন দেওয় বুজা প্রবাসি দের অন্যায়',
#  'দয়া নেগেটিভ খবর প্রচ বন্ধ নীতিকথা বল সময় ভবিষ্যত চিন্তা জরুরী যেটা ভাল হয় প্রচ না ভবিষ্যত চিন্তা দেশপ্রেমিক ভুমিকায় সমস্ত মতবাদ সমন্বয় প্রচ',
#  'প্রশাসন কত নাটক দেখবো ভাই',
#  'অযথা লক ডাউন নাম রিউম লাখ লাখ মানুষ বিপদে ফেললো ইচ্ছা থাকলে বাড়ি ঈদ পার না তাদের ভোগান্তির শেষ নাই সিদ্বান্ত নিলে যেকোনো নেওয়া হয় কঠোর নয় বাদ সকার বুদ্ধি দাতা জুতা গরুর গোবর খাওয়ানো উচিৎ',
#  'দুঃসময় গণস্বাস্থ্য কেন্দ্র কিট হচ্ছেতা সত্যি হিসেব লজ্জাজনক',
#  'বাড়ীওয় বিরুদ্ধে আইনানুগ ব্যবস্থা',
#  'মিথ্যাবাদি করোনায় ধ্বংস হউক',
#  'বাড়াবাড়ি অসহনীয় পর্য পৌঁছ না ঘরে থাক না অন্য ভালো রাখ',
#  'সরক সরকারী ঘুষখোর কর্মচারী অধিকাংশ করোনা পজিটিভ লাখ প্রণোদনা অথচো পারেনা',
#  'করোনা কবে যানিনা মন্ত্রী সাহেবের দ্রুত তার পদ ছাড় যাওয়া',
#  'অন্য না',
#  'বাল লকডাউন কাগজে কলমে প্রাশাসন উদ্যোগ নাই প্রশাসন লকডাউন হইয়া',
#  'বাহ পাগল বাহ গণপরিবহন অফ গনশপিংমল খোল মানে চুতিয়া পানা না',
#  'ডাক্ত মাস ভ্যাকসিন বানিয়ে ফাল শুনি অনুমতি কেবল দিল ডাক্ত ফালতু বক',
#  'ঈদের আম দেশ তার জনগণ দায়ী',
#  'লাঠিপেটায় ব্রাম্মনবাড়িয় নিয়োগ প্রয়োজন',
#  'সচেতনতা বৃদ্ধি',
#  'যমুনা টেলিভিশন ফেসবুক নিয়ন্ত্রণ ভাইবোন বল আপনা মন্তব্য বাক্স বন্ধ বেশিরভাগ অশিক্ষিত নির্বোধ লোকজন আপনাদেরকে বিভ্রান্ত ক্ষমতা রাখে',
#  'স\u200c্যালাইন পানি টিকা বলে চালিয়ে',
#  'পুলিশ ক্ষমতা দেয়া সাধারন হয়রানির শিক ঘুষ পার মাস্ক পড়া লোকজন অজুহা নাজেহাল',
#  'যেই সর্দি কাশি এটা করোনা এই মিথ্যা বক্তব্য দেয় দরক নেই',
#  'হোটেলরেস্তরাবিনোদন স্পটএ বন্ধ শিক্ষাপ্রতিস্টান খুলে দিননা ধংস',
#  'দেশ টিকা উৎপাদন বিদেশ কিন পারবে না কিন না পারলে চুরি পারবে না এই আপনা বোঝা লাগবে',
#  'লকডাউন জরুরি সচেতনতা সরক লকডাউন চালিয়ে সাধারণ লকডাউন অমান্য',
#  'করোন ভয় পাল্ কোথায় চাল চোর ডাল চোর বার মোজাদ্দ চোর কারবারি সুযোগে সত ব্যবহ নিত্য পন্য দাম বারা দেয়',
#  'দেশ বেক্সিমকোস্ক একমি বড় বড় কোম্পানী করোনা টিকা তৈরি ব্যর্থ',
#  'মৃত্যুর সংখ্যা নিউজে দেখি সরকারি প্রচারে পাইনাসঠিক খবর প্রচ মীরজাদি অনুরোধ কর',
#  'স্কুল কলেজ না খোল নতুন ষড়যন্ত্র',
#  'লজ্জা শরম বড্ড অভাবজ্ঞান বুদ্ধি থাকলে নির্বোধ শপিং মারাইতো না',
#  'প্রথম টিকা গ্রহন গরীব গুলোর সর্বনাশ হত না',
#  'ডিম থেরাপি ছাড় তাইলে দিনে বাসা বের না',
#  'দেশ বেক্সিমকোস্ক একমি বড় বড় কোম্পানী করোনা টিকা তৈরি ব্যর্থ',
#  'ঘোড়ারডিম মানুষ ভয় দেখানো ছাড়া',
#  'বাংলাদেশ সরক সচেতন এত স্ট্রং করোন শক্তিশা মন্ত্রি পরিসদ সুন্দর হাসপাতাল সুন্দর ব্যাবস্থা প্রিথীবির বুক বিরল',
#  'সৌদি মাএ হয়েছিল কত নিয়ম চালু করছেক কঠোর ব্যবস্থা নেওয়া হয় বাংলাদেশের হাজারো বেশি ব্যবস্থা নেই নমুনা সংগ্রহ বন্ধ না হয় অনেক কঠোর ব্যবস্থা নেওয়া',
#  'অথচ পাবলিক বলসে আসিফ মাহমুদ নাটক',
#  'এখন লকডাউন ছাড়বে লকডাউন দিয়েছি আন্দোলন বন্ধ সাধারণ পাট লাথি মারা',
#  'ডাক্ত মাস ভ্যাকসিন বানিয়ে ফাল শুনি অনুমতি কেবল দিল ডাক্ত ফালতু বক',
#  'অযতা ফালতু লকডাউন দেয়া হয়',
#  'ভারত আস পিটানো দরক',
#  'কারফিউ জারি থামানো না এদের রুপে পশু এজন্য ফটো বল খাবারের অভাবে রাস্তায় বেরিয়ে আস মন বোঝানো যেত বিনোদন রাস্তায় বেরিয়ে এস তাদের পশুর তুলনা করা পশু ছোট',
#  'আচুদা বেচুদা বাংলাদেশ পয়দা হয়',
#  'পুলিশ হ্যাডাম রিক্সাওয়ালাগো সাথেইভাই পারলে প্রাইভেট উল্টাইয়া রাইখা দেখান',
#  'এইভাবে বিবেকহীন করা হয় নাই বাড়িওয় বাড়িওয়ালাকে শাস্তি',
#  'গুলো মারা প্রয়োজন স্বাস্থ্য কর্মী না আওয়ামী চামচা হাইব্রিড এমপি মন্ত্রী যাদের দল বদনাম টিকা আপনা',
#  'লকডাউন খোলা লকডাউন কতটুকু কার্যকর বুঝি নাশুধু সাধারণ হয়রানি',
#  'আপনা মত সাৎবাদিক আতংকিত',
#  'আশুলিয়া সাভা লকডাউন না বাংলাদেশ থানায় বেশি',
#  'বিশ্ব স্বাস্থ্য সংস্থা আন্তর্জাতিক নোবেল কমি প্রধান বিনীত অনুরোধ স্বাধীন বাংলাদেশের মাননীয় স্বাস্থ্ মন্ত্রী মহোদয় আগামী নোবেল পুরস্কার মনোনীত',
#  'সরক বললো বাড়ি দিবে না এতো যাতায়াত করত',
#  'ওরে বাটপ দুনিয়া করোনা নাই',
#  'সেনাবাহিনী নামা পিটা হাত পা ভাঙ দিক দেখি জনগন না মান কোথায়',
#  'ঈদ\u200c শপ\u200cিং কর\u200cে ঈদ করত\u200cে বাড়ীত\u200cে আস\u200c সাথ\u200cে কাফন\u200c কাপড় ন\u200cা আস\u200c',
#  'মৃত্যু র মামলা প্রয়োজন রাষ্ট্র র বিরুদ্ধে',
#  'ভ্যাকসিন অনুমোদন না বিদেশি হাত পাত ক্ষমতাসীন এদেশের উদ্ভাবনী শক্তি এভাবে পঙ্গু শ্রেনীর তাহাজ্জুদ আাদায়কারী মুক্তিযুদ্ধ খোলসে আবদ্ধ হওয়া মীরজাফর দল',
#  'বাঙা জানে বোতলে ভরে পানি দিছ টিকায় না দাদা টাকা পাঠা টিকা উছিলা',
#  'জনগন হয়রানি বন্ধ করা',
#  'এসব টাকা বরাদ্দ হয় শুধুমাত্র চুর মেম্ব চেয়ারম্যান এমপি মন্ত্রি জনগণ নয়',
#  'চুক্তি অনুযায়ী টিকা না দেয়ায় ভারত বিরুদ্ধে মামলা',
#  'করোনা না থাকলে জানতে পারতাম না সকল মানসিক অসুস্থ বসবাস',
#  'করোনা বাংলাদেশের পালটাইনি বরং বাংলাদেশের চোর আসল চেহা বাহীর হচ বাঙা কত নিন্ম শ্রেনীর পুরো পৃথীবি দাখ',
#  'মন্ত্রীর চোখে না টাকায় এসির নিচে বসে বসে লকডাউন দেয় বুঝবে গরিব কষ্ট',
#  'গরুর মুত ছাড়া ওতে অার নেই',
#  'নাটক ফাঁদে পঙ্গু শিক্ষা ব্যবস্থা',
#  'বেবিট্যাক্সি রিক্সা গার্মেন্টস দোকানপাট শপিংমল যেগুলো বন্ধ খুলে প্রতিদিন সাড়ে হাজা শনাক্ত',
#  'ফেসবুক ছাগল বাচ্চা লাফালাফি টিকা দরক',
#  'বাংলাদেশের সকল জেলাউপজেলা ইউনিয়ন পর্য সকল চেয়ারম্যান মেম্বার গোয়েন্দা নজরদারি রাখাহোক ত্রান চুরি না',
#  'সরক গরিব সরক না গরীব পাট লাত্তি মারে মানি না লকডাউন কিস লকডাউন গরিব মারা লকডাউন সরকার আল্লাহর গজব আসতেচ',
#  'প্রশাসন কত নাটক দেখবো ভাই',
#  'লকডাউন ষোল হাজা টাকা বেতনে চাকরি প্রতিদিন আড়াইশো টাকা ভাড়া লাগে বলবো দুই বাচ্চা মা বউ বাসা ভাড়া স্তি চলবো লকডাউন সমিতির কিস্তি বন্ধ নাই তোমরা হলুদ সাংবাদিক সারাদিন তেল মার ব্যস্ত থাকো গরিব কথা তোমরা সরকার বল সাধারণ গরিব কিস্তি বন্ধ',
#  'দেশি ভ্যাক্সিন তৈরি এদেশের চোর চুরি একটু কঠিন এজন্য অনেক উদ্ভাবন আলোর মুখ দেখেনি ভ্যাক্সিন চোর দাপটে অন্ধকারে রয়',
#  'এগুলারে ডায়রিয়া আক্রান্ত রুগির জাইঙ্গা দিয়া পিটানো',
#  'নৃশংস ডাক্ত নাম শশু ওনা মত মহান মন শিক্ষা নেয়া দরক বিপ সময় ছার পালা বেড়ায়যা টাকা জন\u200d্য ডাক্তারি',
#  'দেশটারে লুই পুই খাবা তোমরা জনগণ দেখ দায়িত্ব বড়লোক',
#  'সমবেদনা মীরজাফর নায়ক সাফল্য হাসি উড়া দিয়েছিল',
#  'আদা পাগলা বালচাল শুুধু ইন্ডিয়াতেই পাওয়া নেতা ভাবতে অবাগ লাগে',
#  'কচুর লকডাউন মারা লকডাউন বড় লোক বড় সুযোগ গরীব পিশে মারা লকডাউন',
#  'শিক্ষা ব্যবস্থা ধ্বংস দ্বারপ্রান্ পৌছ',
#  'মার',
#  'আহহারে বড় স্বার্থপর',
#  'রোগী মুখে মাক্স নেই কেনগরু ছাগল সকুল খুলে না দেওয় তামাশা দরক নেই',
#  'মিথ্যাবাদি করোনায় ধ্বংস হউক',
#  'কচুর লকডাউন মারা লকডাউন বড় লোক বড় সুযোগ গরীব পিশে মারা লকডাউন',
#  'সরক মজা নেয় দেখ দুরপাল্ল বাস চল পার কারনে চুপ বসে',
#  'বেহুদা বংশ ঢাকায় বেহুদা ঢাকা বাইরে বেহুদা',
#  'দেশ জন্ম নেওয়া পাপআর সাস্থ্য খাত সেনাবাহিনীর হাত পুরোপুরি দিলে সবচাইতে ভালো হয়আর জনগণ টাকা খরচ ডাক্ত হব ডাক্ত গুলোর আচরণ পশুর জায়তা দেশ গনপরিবহন ডাক্তারি শিক্ষা বেশরকারি হোকমানুষ টাকা বিনিময় অন্তোত সেবা পাবে',
#  'কসাইরা ভাল হওয় না নেশা সুদু টাকা সেবা না',
#  'গণপরিবহন সীমিত আসনে চলাচল করোনা সংক্রমণ কম হত পরিবহন শ্রমিক কষ্ট হত না ভোগান্তি পোহা হত না',
#  'সব পাগলামি ছার না বলে আরক বার বলে গাঁজা খায় কথা বলে ডিসিশন এত সমস্যা',
#  'লাশ আতঙ্কবলা জীবন্ত করোনা রোগী তিনফুট দূরত্ব বজায় রাখলে নিরাপদতাহলে লাশ যোজন যোজন দূরত্বে থাক',
#  'নাটক সাজানোর আছেসরক শিক্ষা প্রতিষ্ঠান খুল না সোজাসাপ্ বলে দিলে',
#  'পুলিশ জঘন্যতম পর্য',
#  'মুর্খ',
#  'জনগণ সেবক হিসেব কথা জনগণ রাজা মত আচরণ করত ধিক্ক এইসব অমানুষ এসব অপেশ পুলিশ বিচ',
#  'পাট ভাত নাই কিস ললডাউন করেমানুষ কর্ম বন্দ করোনা নিয়ন্ত্রণ করুকবাংলাদেশ সরক বিদেশের খাবা পারেএ বাসায় লকডাউন করেভা মরবে অসুখে মরবেআল্লাহ ভয় নয়মহামারি আস আল্লাহর হুকুম আল্লাহর হুকুম',
#  'এই কখনো অনুমোদন পাবে না তাহলে সরকারি কুত্তা পকেট ভরবে না',
#  'দূরপাল্ল বাস খুলে খুলে দূরপাল্ল বাস বন্ধ কেনো মানি না',
#  'সালে সরক বাজেট পেশ স্বাস্থ্য খাত বাড়া এভাবে রাস্তা ঘাটে মরে থাক না স্বাস্থ্য মন্রী মূর্খ বর্বর পদক্ষেপ',
#  'পরিবহন চালু নাই ভালো কথা শ্রমিক না খায় তার খোঁজ আপনা নেওয় কথা ছিলো',
#  'করোনা নিয়ন্ত্রণে থাকলে ঘরে বসে ব্রিফিং না বাইরে বের হোন',
#  'ফাইজলামি জায়গা পায়না এতদিন বলে ভ্যাকসিন নিলে করুণা উড়ে বলে ভ্যাকসিন নিলে সমাধান হবেনা হাস্যকর না পাবলিক বুঝে',
#  'লকডাউন সরকার ভুল সিদ্ধান্ত সাধারণ মর খাড় ঘা লকডাউন করোনা ভাইরাস মুক্তি সম্ভব না',
#  'ভবিষ্য পরিস্থিতি অনেক খারাপ লোকজন উদাসীনত',
#  'ভাগ্য ভালো ইউরোপ আমেরিকার অবস্থা নি হত বাঙালির লাশ কুকুরে খাইতো',
#  'দেশি ভ্যাক্সিন তৈরি এদেশের চোর চুরি একটু কঠিন এজন্য অনেক উদ্ভাবন আলোর মুখ দেখেনি ভ্যাক্সিন চোর দাপটে অন্ধকারে রয়',
#  'দেশ কেনো নাটক যতগো প্লেনিং কর ফেল কেনো জান মগেরমুল্লুকের রাজা বলব জনগন মান বাদ্য হল চাল চুরি ডাল তেল চুরি শেষ মেষ শপিং মল দোখান পাট সীমিত আকারে কোলা এসব যায়গায় জনগন মানে নি জনগন গল কাঁ দাঁড় সরক করোনা অবেস্তা না গিল না পেল',
#  'বাড়ি কোয়ারেন্টাইন মানবে নাকষ্ট হলে জনগন স্বার্থে কড়কড়ি',
#  'করোনা না থাকলে জানতে পারতাম না সকল মানসিক অসুস্থ বসবাস',
#  'করোন নামে দুর্নীতি ছাড়া দেখ না দেশ ধ্বংস পাঁয়তা চল',
#  'বাঙালী মর আগে সচেতন না',
#  'সাহে মত পাপিয় মতদেশের বেইমানী চুরি ডাকাতি জীবন যাপন কর ঠিক ছিলো যত্তসব ফাউল লোকজন',
#  'পাগল বানা ভারত কত ভাঙ্গাবে হাও টিকায় হইনা',
#  'আপনা অনেক বেশি ছড় কিছুদিন ফালতু পোস্ট বিরত',
#  'স্বাস্থ্য ব্যবস্থা দুর্বল',
#  'জড়া ধরুন অক্সিজ দিবি নাত ভালোবাসা নে',
#  'গজব দেশ বাংলাদেশ অবৈধ স্বৈরাচারী শেখ হাসিনা অবৈধ ক্ষমতায় থাক সমস্ত অবৈধ উন্মুক্ত',
#  'আপনা জোড় করোন আতংক বাড়াচ্ছেনকিস দ্বিতীয় ধাক্কায় পড়বে বাংলাদেশ ফালতু কথা',
#  'টিক অনুমতি দিলে চোরে ব্যবসা বন্ধ',
#  'জানোয় পুলিশ হালা হাবিলদ একএক কথা বলে রাজা বেশ',
#  'অক্সিজেনের ব্যবহ নেইসেখানে বল সামাল পারছেনাসব মিথ্য অযুহাততা অন্যভাবে সিন্ডিকেড করত',
#  'ভাওতাবাজি কত প্রধানমন্ত্রী শেখ হাসিনা একটু বই',
#  'সকল দায়িত্বশীল লোকজন কর্মকর্তা আধুনিক করোনা ভাইরাস কভিড সংক্রমণ নিয়ন্ত্রণে সার্বিক প্রস্তুতি সার্বিক ব্যবস্থাপনায় নিজে ইউরোপ আমেরিকার চায় শক্তিশালী সের ভালো বলে দাবী',
#  'আল্লাহ সহায় থাক নিকট এক আবেদন ব্যাক্তিগত গাড়ি করোনা মরে',
#  'করোনা মহামারি পুঁজি সাধারণ জুলুম কর আল্লা রাব্বুল আলামিন কঠিন বিচ',
#  'দি বাংলাদেশের অবস্থা ভারত সরকার পাশাপাশি জনগন দায়ী',
#  'জনগন ভোগান্তি সরকার চোখে না খোলা রাখলে খোলা রাখুন বন্ধ রাখলে বন্ধ রাখুন সরকারি টাকা চললে বাল ছাল সিদ্ধান্ত কস্ট না সরক সাধারন সরকার কথা মান চলবে দেশ কারো কথায় না অযথা জনগন ভোগান্তি বাড়ানোর উল পাল্ সিদ্ধান্ত গ্রহন না',
#  'বাল লকডাউন এই হেফাজত ডাউন',
#  'হালা গাঁজা খাই তিনমাস মাতাল হল',
#  'বাংলাদেশ র আসল ঘটনা প্রকাশ হয় না বিভিন্ন জায়গায় রাস্তায় ব্যারিকেড কাস ঠিক এম্বুলেন্স কিভাবে হায়রে বাঙা বুঝস বুঝ মারা লাইন বুঝস',
#  'গরুর মুত',
#  'বিশেস ফ্লাইট নামে প্রবাসি জবা বন্ধ হোটেল কোয়ারেন্টা বন্ধ না প্রবাসি খেপলে বিপদ',
#  'এসব নাটক কবে বন্ধ আপনা',
#  'চলতি মাস শাষ শিক্ষা প্রতিষ্টান খুল কথা ছিলো বলে করোনা বাড় ওরে বাটপ',
#  'কিন্ডারগার্টেন মানে ব্যবসা প্রতিষ্ঠান শিক্ষা ব্যবস্থা নস্ট কিন্ডারগার্টেন দায়ী',
#  'হাত না ধুইলে পুলিশে ধুয় দাব মুখে কাপড় না থাকলে পিট পাছা কাপড় ফেলবে এইব ঠিক',
#  'দেশ বর্তমান করে চালা হসপিটাল প্রাইভেট মেডিক্যালগুলু জমজমাট ব্যবসা চাল যেকোনো রোগী মেডিক্যালে গাল বল করোনা হয়',
#  '\u200cযেমন কর্ম ফল',
#  'ঈদের নামাজ পড় মসজিদে শপিংমল খোলা এগুলা মুসলমান তামাশা ছাড়া না',
#  'বর্তমান প্রেক্ষাপটে স্বাস্থ্যসেবা ঢাল সাজা স্বাস্থ্যমন্ত্রীর পদত্যাগ অবশ্য জরুরিকারন করোন মহামারীর বছর বেশি সময় পার হলে তার সাফল্য জিরো হলে দুর্নীতি হিরো হয়েছেন',
#  'দুর্নীতিবাজ একসময় ছাত্রছাত্রী',
#  'চিকিৎসা পায় না দেশ দেয়',
#  'অনুমতি দেয় নাই পাছা চামড়া লবন দেয়া দরক',
#  'রাখ ক্ষমতা পায় জুলুম ইতিহাস ক্ষমা নাই',
#  'সরক ফটকাবাজ প্রমাণ করলো দুই দিন রিপোর্ট আজক রিপোর্ট প্রমাণ নমুনা দেশ চোর সরক এইভাবেই',
#  'আপনা মিডিয়া কত রখম আবাল মার্কা পোস্ট দয়া এরখম পোস্ট না কেননা পাবন মানসিক হাসপাতালে রোগীর সংখ্যা বৃদ্ধি পেত',
#  'অর্ধেক আসন ফাঁকা বাস চলাচল দরক নেই সাধারন জনগণ লাভ নেইএখন অটো সিএনজিতে দিগুণ ভাড়া নেয় দেখ নাই সুতরাং লাউ কদুঁ জনগণ উভয় সংকট ন্যায্য ভাড়ায় বাস গণপরিবহন নামানো',
#  'ঘোড়ারডিম মানুষ ভয় দেখানো ছাড়া',
#  'স্বাভাবিক বিমান চলাচল করেনটাইন বাতিল',
#  'করোনা ভাইরাস খেলা লগডাউ সিথিল সকাল বিকাল পরিবর্তন সাধারন পাবলিক করোনাভাইরাস বোঝেনা বাংগালী বোঝে খাও হাগো',
#  'চায়না ওষুধ আবিষ্ক নাই বাংলাদেশ বাল করবো চায়না বাংলাদেশ আসতা আলাদা থাকা জায়গা তৈরী কম হয়লে জানি মাস জানি ছাড় না পরিবার সদস্য আসতাছ আপনা বুঝে বাসায় যাইয়েনআপন পরিবার সদস্য জানি সমস্যা না সতর্ক',
#  'সাফল্য প্রধান শত্রু বেক্সিমকোর মালিক রক্তচোষা সালমান এফ রহমান',
#  'বাংলাদেশের পুলিশ বড় ডাকাত হারাম খোর রাত অন্ধকারে পতি গাড়ি টাকা দূর পাল্ল বাস সার্ভ দেয়',
#  'হাসপাতাল বুমা মার উড়া দরক কারন রোগি হাসপাতালে নাদেখা হ য় হাসপাতাল দরক নাই',
#  'স্বাস্থ্যবিধি মানা সরক জোরালো আইন',
#  'জানোয় পুলিশ হালা হাবিলদ একএক কথা বলে রাজা বেশ',
#  'প্রবাসী রেমিটেন্স খুব ভাল লাগে প্রবাসী কারো ভাল লাগেনা শালা দেশ',
#  'অনেক সহজে টিকা ছাড়া সকল করোনা ভাইরাস কয়েক মিনিট ভেতর নিস্ক্রিয় সকল মিডিয়া সেটা ব্যপারে কথা বলেনা এদেশের ঔষধ ব্যবসায়ী নিয়ন্ত্রিত সহজ পদ্ধতির কথা বললে অকাল কুস্মান্ডোর হাসি পায় না ভুয়া বলে কারন দৌড়',
#  'প্রশাসন দৃষ্ আকর্ষণ করছিঐ তথাকথিত বাড়িওয়ালাকে আইন আওয়াতায় আনা দৃষ্টান্তমূলক শাস্তি',
#  'এই বাংলাদেশ জিবন মুল্য নেই দেশ',
#  'টিক অনুমতি দিলে চোরে ব্যবসা বন্ধ',
#  'সরক চোখে আল্লাহর গজব পড়ুক কষ্টে বিদেশ বাড়ি ব্যাংক ব্যালেন্স করত বলত দেশ গরীব নাই',
#  'সব পাগলামি ছার না বলে আরক বার বলে গাঁজা খায় কথা বলে ডিসিশন এত সমস্যা',
#  'দেশ পিপি সংকট নাই চিড়িয় প্রাণি কই',
#  'এভাবে সপ্তাহ সপ্তাহ না তামাসা না পুরুপুরি বছর লকডাউন দিলে গরিব মরে যাক গরিব শেষবড়লোক বাংলাদেশ',
#  'শালারপুত বর্ড উম্মুক্ত রাখ ভারত এতসব পর যোগাযোগ বজায় রাখ তাদের কুত্ত ধোলা',
#  'এইদেশ অনেক করোনায় আক্রান্ত নিরাপত্ত বাড়িওয়ালাকে দেশ বের',
#  'টাকা নেশায় দৈনিক রুগী ডাক্ত চেম্ব বন্ধ বাসায় বসে জীবন বাচায়',
#  'হয় এভাবে হাজারো মৌমাছির প্রান জেত মোটে উচিৎ নয় মৌমাছির কারনে করোনা বৃদ্ধি পাবে',
#  'লকডাউন খুলে দয়া লাগবে না তাছাড়া এই জনগন টাকা খাট খেত জানে',
#  'দালাল ছাড়া না কর্মর আছ গুলা বড় দালালআমি মাস',
#  'দিনে তৈরী হয়নি মহা অব্যবস্থাপন খাত দেখা পারবেনা রকম নৈরাজ্য বিরাজ না',
#  'কিস টিকা সব বাটপারি তেলবাজি',
#  'পুলিশ সেবক বলব চাকর বলব বোঝা',
#  'কাক বুঝাবেমনির্বোধ নিজে বড় বুদ্ধিমান বিপদজনকএ বিরুদ্ধে আইন ব্যাবস্থা নেয়',
#  'করোনা মানুষ নতুন পরিচয় করা দেয় হিংস্র পশুর চায় জঘন্য পাশবিক অমানবিক',
#  'বুঝ না সাহায্য তার বেশির ভাগ ব্যাক্তিগত উদ্যোগে সরকারী সাহায্য অনুদান কোথায়',
#  'সরক বাড়ি ভাড়া মাফ বাড়ি এল মাপ করতেস না কর এটা ব্যবস্থা',
#  'খুব বেশি দেরি নাই পাবলিক আইন হাত কেউও পালানোর পথ খুঁজে পাবে না',
#  'সরক অনুদান দেয় কার পায় অনুদান টাকা না পকেট ডুক',
#  'দেশ বর্তমান করে চালা হসপিটাল প্রাইভেট মেডিক্যালগুলু জমজমাট ব্যবসা চাল যেকোনো রোগী মেডিক্যালে গাল বল করোনা হয়',
#  'ভারত ভিক্ষা বাংলাদেশ অক্সিজ উৎপাদন পারছেনা',
#  'পুলিশ প্রসাশন রিকশা ভ্যান অটো চালক পারফেক্ট জায়গা চুদা না',
#  'মাক্স না পড়লে শাস্তি দেয়া অযথা করোনা টেস্ট সরক অর্থ নষ্ট বুঝি না',
#  'রাজাকারের বাচ্চা পাকিস্তান দালাল মিথ্যাচারের দায়ে বিরুদ্ধে আইনানুগ ব্যবস্থা নেয়া',
#  'সরকার আসকা পায় জানোয়',
#  'বাংলাদেশ সরক একেবারে ব্যর্থ',
#  'অর্ধেক আসন ফাঁকা বাস চলাচল দরক নেই সাধারন জনগণ লাভ নেইএখন অটো সিএনজিতে দিগুণ ভাড়া নেয় দেখ নাই সুতরাং লাউ কদুঁ জনগণ উভয় সংকট ন্যায্য ভাড়ায় বাস গণপরিবহন নামানো',
#  'ভবিষ্য পরিস্থিতি অনেক খারাপ লোকজন উদাসীনত',
#  'লকডাউন খোলা লকডাউন কতটুকু কার্যকর বুঝি নাশুধু সাধারণ হয়রানি',
#  'এই গার্মেন্টস ফ্যাক্টরি চালু ফল শপিংমল খুলে দেয় ফল এখনো বাকি বাংলাদেশ কটা সবুর করোনা বাংলাদেশের ঘরে ঘরে পৌঁ',
#  'কিছুক্ষণ টিভি দেখ দোকানপাঠ বন্ধ রাখা কারনে অনেক ক্রতা ক্ষু্দ্ধ দোকান মালিক সমালােচনা করছেএগুলো',
#  'সরকারি র দালাল ঝমুনা',
#  'কচুর লকডাউন মারা লকডাউন বড় লোক বড় সুযোগ গরীব পিশে মারা লকডাউন',
#  'অপেক্ষায় থাকো তোমা মূর্খ কারনে ইন্ডিয় ভয়াবহ অবস্থা বাংলাদেশ',
#  'বাংলাদেশের কোথা করোনা নাই ভন্ডামী',
#  'বাপ জন্মে কোনদিন নাই হয় জন্ম প্রথম এইট আসলে যতদিন না ডাঙ্গা পুলিশ ধার জারি না ততদিন বাংলাদেশের মানুষ সুরক্ষিত না মত কারনে ঈদের বাংলাদেশের মানুষ দাফন জায়গা না',
#  'কড়াকড়ি আরোপ',
#  'মার্কেট খোল সু ফল এখনো পুরোপুরি পাওয়া যায়নি অপেক্ষা',
#  '\u200cযেমন কর্ম ফল',
#  'কথায় কথায় কমি গঠন যেদিন কমি গঠন এদেশ বিতাড়িত সেইদিন সোন বাংলা',
#  'বাংলাদেশের সকল জেলাউপজেলা ইউনিয়ন পর্য সকল চেয়ারম্যান মেম্বার গোয়েন্দা নজরদারি রাখাহোক ত্রান চুরি না',
#  'সীমান্ত অফ না মৃত্যু খুব মজা',
#  'বিবেক মূল্যবোধ দুটোর অভাব আজকাল',
#  'দেশ জনগন নিয়া সরক তামাশা',
#  'সরক দুর্নীতিবাজ দেশ ভালো পথে',
#  'অন্যদি সরক ট্যাক্স বাড়া সরকারি কর্মচারীসহ পেট ভরাট ব্যস্ত এই দেখ নেই',
#  'লকডাউনে পুলিশ চাঁদাবাজি কমে সাধরণ জনগন ঝাল মেট',
#  'মৃত মানুষ দাই ডাক্ত ডক্টর দের চাকরি চূত দরক তাদের হাল চাষ করানো ঊচিত',
#  'নাটক বন্ধো জনগন পাগল না নাসিন দালাল জনগন মোটিভিশন আসছ',
#  'সরকার গজব পরুক',
#  'সাস্থ\u200c্য বিভা\u200cগ চোর গু\u200cলে প\u200cরি\u200cস্থি\u200cতি',
#  'এগুলা ডাক্ত না কসা বাংলাদেশের অবস্থান সাধারণ মৃত্যু এভাবে',
#  'গরীব মরে সরকার সমস্যা ভালো থাকা তারা দিব্যি সরক গঠন তোমা ভোটে হই তোমা ভোট দরক হবে না সরক জনগন মুখাপেক্ষী না তোমা সুবিধা অসুবিধায় সরকার',
#  'কারেন বিল ঘরে পুছ খাবা পুছেবেনা সরকারে এসব খাবা চুরি বোরলোক চায় এসব গরিব হক',
#  'বিশ্ব স্বাস্থ্য সংস্থা আন্তর্জাতিক নোবেল কমি প্রধান বিনীত অনুরোধ স্বাধীন বাংলাদেশের মাননীয় স্বাস্থ্ মন্ত্রী মহোদয় আগামী নোবেল পুরস্কার মনোনীত',
#  'সর্ব প্রথম দূর্নীতিবাজ টেন্ড বাজ ভোট চোর ভ্যাকসিন হোকওরা মরলে দেশ নিরাপদ বাচলে ভ্যাকসিন নিরাপদ',
#  'কেমন লকডাউন রাস্থায় ঘোরাফিরা',
#  'বড় স্বাথ',
#  'পুলিশ উচিৎ বাধা জানোয় গুলো থানায় শিক্ষা দেয়া লাশ দাফন মৃত ব্যক্তির জাগায় তোদের বাপ জাগায় না পিঠ চামড়া ফেল দরক',
#  'দালাল ছাড়া না কর্মর আছ গুলা বড় দালালআমি মাস',
#  'মনগড়া খবর',
#  'দেশ লক্ষ লক্ষ অভাব আনাহারে দেশ হাজা হাজা কুটি টাকা খর মুর্তি বনায়মানবত মৃত্যু হয়',
#  'পুলিশ সেবক বলব চাকর বলব বোঝা',
#  'এই সরকার মনিটরিং',
#  'দেশ বেক্সিমকোস্ক একমি বড় বড় কোম্পানী করোনা টিকা তৈরি ব্যর্থ',
#  'করোন ভয় পায় নাকরোন অজুহাত ছাল মেয়ের জীবন অন্ধক শিক্ষা প্রতিষ্ঠান বন্ধ',
#  'হয় এভাবে হাজারো মৌমাছির প্রান জেত মোটে উচিৎ নয় মৌমাছির কারনে করোনা বৃদ্ধি পাবে',
#  'অসচেতন জাতির ডান্ডা ছাড়া উপায় নাই অসভ্য জাতি বাঁশ সোজা',
#  'একদম ঠিক আছেবেশী বেশী আক্রান্ত হোকমৃত্যু হোকআনন্দ বের সবারফালতু অসভ্য বাঙ্গালিআরো বারুকঘরে থাক মন চায় নামার্কেট',
#  'কঠোরতা নয় অমানুষ পরিচয় দেয় পুলিশ',
#  'হারামীর ঘর হারামীরা ঘরে খাদ্য সহায়তা পৌছ দে দেখবি এমনিতে ঘরে',
#  'ভাই মিষ্ মিষ্ কথা বললে না লেজ একটু বাকা',
#  'অবৈধ সরক লকডাউন রাজনৈতিক হাতিয় হিসেব',
#  'বড় ভ্যারিয়েন্ট দালাল মিডিয়ামানুষ অাতঙ্কিতভয় লাগানো ছাড়া অার নাইএদেশের গরিব মারা এসব ফাজলামিএসব কারনে উপর মহল লকডাউন কথা',
#  'রাইখ উন্নয়ন জোয়ারে ভাঁ পড়া কবলে বিনা চিকিৎসায় মার কুত্তা টাকায় বিদেশ সামান্য চিকিৎস',
#  'ব্যক্তিগত গাড়ি নেইতারা কিভাবে বাড়ি এদেশ সবারদেশ দুই শ্রেণী ভাগ',
#  'স্বাস্থ্য খাত দুর্নীতির মহাসাগরে পতিত',
#  'সেনাবাহিনী না বাংলাদেশের কখন লকডাউন মানবে নাসরক সেনাবাহিনী নামা দিক সপ্তাহ জন\u200d্য হলেওদেখ সাস্হ\u200d্যবিধি মান ঘরে বসে',
#  'ওরে বাটপ দুনিয়া করোনা নাই',
#  'লকডাউন চায়না',
#  'বুঝি না ফেরি কিভাবে চলাচল প্রসাশন দৃষ্ আকর্ষণ কর বাড়ি পরিবার মৃত্যুর না',
#  'পুলিশ আশা না দল দালা জনগন জানমাল লুণ্ঠন',
#  'বসে বসে খাও পেচাল পাড়এ পযর্ন্ত দেখ না করোরোনা রুগি সালা আজাইরা পেচাল',
#  'সচেতনতা বৃদ্ধি',
#  'চীন তাড়া নিজে তৈরি ভাইরাসতারা ব্যাবসা',
#  'মর শালা তোদের কপালে কারন তোরা উন্নয়নশীল বাংলাদেশের নাগরিক অনেক দুঃখ কথা বল সময় টাকা ফুর্তি মার আল্লাহ রক্ষা',
#  'একটাইতো কিন নাআবাল দুই কেমতে',
#  'দুঃসময় গণস্বাস্থ্য কেন্দ্র কিট হচ্ছেতা সত্যি হিসেব লজ্জাজনক',
#  'খুব দ্রুত লকডাউন ঘোষনা লাগবে',
#  'আসিফ ভাইয় চোখ পানি সময় সত্য হয়েছেকিছু মূর্খ বাঙা সময় কত বাজে মন্তব্য ছিলওনি বুঝিয়ে দিল আমরা',
#  'স্বাস্থ্য মন্ত্রী জাহিদ মালেকের পদত্যাগ দাবি কর বইমেলা সহ আয়োজন বন্ধ জোর দাবি কর',
#  'ভাবমূর্তি পাগল ছাগল',
#  'সরক নিয়ন্ত্রণ পার না লক ডাউন নেয় না জনগণ ভোগান্তি দেব অধিক নেই সরকার',
#  'হুন্ডি টাকা পাঠা দেশ রেনিটেন্স বঞ্চিত না ভাবলে কেনো ভাববো',
#  'বাংলাদেশ চিকিৎসা ব্যবস্থা খারাপ বর্তমানে দুর্যোগ না বুঝতাম না দেশ অনেক পেছনে',
#  'সরকার নজরদারি খুব দরক সরকার অসাদু কর্মচারির বাংলাদেশের ভিতরে ভারতীয় রোগ নির্ণয় না',
#  'দুয়া আল্লাহর আজাব সুট বড় সব হলে দুনির তোরা ডুর বিতর আসবে দুনিয় পশুর খারাপ',
#  'স্বাস্থ্য খাত দুর্নীতির মহাসাগরে পতিত',
#  'আইন গরিব ব\u200d্যাক্তিগত গাড়ি ধনী ঈদ বাড়ি গরিব যাব হাওয়াতেদুঃখ',
#  'নাটক আওয়ামী লীগ সরক যাব বিশ বছর',
#  'মিডিয় বিরুদ্ধে মামলা কর ফাঁসির মঞ্চে হাইকোর্ট আপিল কর আসলে চায় মৃত্যু জান মাল তামাশা',
#  'সরকার নীতি গরীব প্রতি অবিচ হয়েছেঅনুমতি সবাইকে না না',
#  'চিকিৎসক অবহেল কারনে রোগীর অবস্থা',
#  'মেরুদণ্ডহীন মন্ত্রীর লজ্জা সরম বল গত বছর ডেংগু মহামারি পদত্যাগ করতএক অপদার্থ',
#  'পৃথিবী কুসংস্ক মানে তার সমস্ত ইন্ডিয় ভিতরে প্রধানমন্ত্রী গরু পূজা কত পাবলিক কত ভালো',
#  'অনতিবিলম্বে অনলাইন ক্লাস নামে সকল তামাশা বন্ধ সেপ্টেম্বর শিক্ষাপ্রতিষ্ঠান খুলে',
#  'বিশেষজ্ঞ দেশ টাক নষ্ট করলো',
#  'নাটক বন্ধো জনগন পাগল না নাসিন দালাল জনগন মোটিভিশন আসছ',
#  'কুত্ত বাচ্চা পরীক্ষ সংখ্যা উল্লেখ করপরীক্ষা বাড়লে শনাক্তকরন কমবে',
#  'প্রধানমন্ত্রী বাংলাদেশ করোনা মুক্ত সহ্মম হয় লকডাউনে না বিভিন্ন জায়গায় ছড়িয়ে পরি বাংলাদেশ করোনা থাকলে সরক লকডাউন খুল না',
#  'হাত না ধুইলে পুলিশে ধুয় দাব মুখে কাপড় না থাকলে পিট পাছা কাপড় ফেলবে এইব ঠিক',
#  'লোকদেখানো প্রস্তুতি প্রণোদনা প্যাকেজ কাক দেয়',
#  'আপনা অনেক বেশি ছড় কিছুদিন ফালতু পোস্ট বিরত',
#  'ভারত ভ্যাকসিন নিষিদ্ধ ঘোষণা',
#  'করোনা বাড়ে নাইমোদি বাংলাদেশ আস পথ পরিস্ক করত বিক্ষোভ না',
#  'বাঙা ব্যর্থ প্রমান',
#  'রেমিটেন্স যোদ্ধা বিবেকহীন সরক পিটানো উচিৎ জন\u200d্য দেশ করোনা এস',
#  'দেশ লক্ষ লক্ষ অভাব আনাহারে দেশ হাজা হাজা কুটি টাকা খর মুর্তি বনায়মানবত মৃত্যু হয়',
#  'কারণে লকডাউন লকডাউনে করোনা সংক্রমণ কমে কখন না লকডাউন মানে বন্ধ দেশ লকডাউন মানে ধনীর আয় চাকা সচল সাধারণ নিম্ন আয় পথ বন্ধ ধরন লকডাউন সেটা মাথায় আসল না',
#  'গণপরিবহন বল বিমান বুঝায় না মানে বিমান চলাচল ছাড়া বাকি সব চলত বল',
#  'উচ্চ পর্যায় দায়িত্বশীল জায়গা অদক্ষ অশিক্ষিত মূর্খ বর্বর বসানো হয় দেশ মানবতা বিবেচনা বল না পৃথিবীর একমাত্র দেশ বাংলাদেশ ধনী সবকিছু ওপ রকম অবস্থা গরীব হয় সবসময় অবিচ অত্য ধিক্ক আইন এদেশের নিয়ম',
#  'গণপরিবহন শ্রমিক ধান্দাবাজ তিন ডবল ভাড়া বেশি ঝামেলা পাকাবে',
#  'লোকদেখানো প্রস্তুতি প্রণোদনা প্যাকেজ কাক দেয়',
#  'হাজারে ইস্কুল বন্ধ হয় টাক দেখাবে সরকার অনুদান পাওয়া অনুদান টাকা চোরে ভাগাভাগি খাইতে',
#  'বাংলাদেশ গরিব জন্ম নেয়া পাপ পুলিশ রা কানায় কানায় বুঝা দেয় লানত গরিব অত্য',
#  'মর শালা তোদের কপালে কারন তোরা উন্নয়নশীল বাংলাদেশের নাগরিক অনেক দুঃখ কথা বল সময় টাকা ফুর্তি মার আল্লাহ রক্ষা',
#  'নাও যত খুশি করোনা যাও বেশি বেশি বাইরে যাও',
#  'বাংলাদেশ র আসল ঘটনা প্রকাশ হয় না বিভিন্ন জায়গায় রাস্তায় ব্যারিকেড কাস ঠিক এম্বুলেন্স কিভাবে হায়রে বাঙা বুঝস বুঝ মারা লাইন বুঝস',
#  'মিডিয়া বল বাটপারি ছারো তোমরা করছো বাংলাদেশের ফিটা খায়',
#  'দেশ আসলে চুশে খাইওদেরকে খাওয়ানো',
#  'এইদেশ অনেক করোনায় আক্রান্ত নিরাপত্ত বাড়িওয়ালাকে দেশ বের',
#  'পাশ দেশ ইন্ডিয়ায় পাকিস্তানে ভাড়া সময় হাজা টাকা সিঙ্গেল টিকেট নেয়া চোর দেশ হাজা টাকা প্রশ্ন কত টাকা বাড়লে জানোয় গুলোর চোখে পড়বে প্রবাসী কষ্ট কথা',
#  'এদেশের বিশেষজ্ঞ করোনা সম্পর্ জ্ঞান নেই কথায় সততা পাওয়া না',
#  'অবহেলা চরম মুল্য',
#  'স্বাস্থ্য মন্ত্রণালয় এতটুকু নিশ্চিত না পারলে হাসপাতাল করোনা চিকিৎসা',
#  'জঘন্য সিস্টেম করোনা আক্রান্ত ডাকঢোল পিটা পুরো এলাকা পুরো হসপিটাল সকল ডাক্ত নার্স কারাগারে আইসোলেশনে পাঠানো কিভাবে ডাক্ত চিকিৎসা সাহস পাবে',
#  'এতো বিধি নিষেধ মানা কথা সরক খুলে দিলোআব লক ডাউন খাট খাওয়া লোক মারছেনগন পরিবহন চলবেশপিংমল খোলা প্রজ্ঞাপন জারি ঘোষনা হচ্ছেসরক হাস্যকর ব্য',
#  'ঘোড় ডিম ডিম বাচ্চা তার বাচ্চা বড় একদিন সেনাবাহিনী আরকি সঠিক পথে পরিচালিত',
#  'শপিং মল খুল পারতেছেন পলিটেকনিক পরিক্ষা পারতেছেন না ঝুল রাখছ ফালতু রাজনীতি',
#  'পুলিশ বেশি আশা ঠিক না এই মত হলে কর্মকাণ্ড পশুর চায় নিকৃষ্ট সময় এস এদের পরিব সামাজিক বয়কট',
#  'একদম ঠিক আছেবেশী বেশী আক্রান্ত হোকমৃত্যু হোকআনন্দ বের সবারফালতু অসভ্য বাঙ্গালিআরো বারুকঘরে থাক মন চায় নামার্কেট',
#  'দেশ টিকা উৎপাদন বিদেশ কিন পারবে না কিন না পারলে চুরি পারবে না এই আপনা বোঝা লাগবে',
#  'সকল প্রাইবেট হাসপাতাল আইন মুহূর্ বন্ধ সরকারি হাসপাতাল চিকিৎসা ব্যবস্ত মান উন্নত গরিব ধনী সরকারি হাসপাতাল চিকিৎসা নেই সমান সরকারি হাসপাতাল চিকিৎসা ব্যবস্ত পরিবর্তন আসবে বৈষম্য থাকবেনা',
#  'রাখ ক্ষমতা পায় জুলুম ইতিহাস ক্ষমা নাই',
#  'কাক বুঝাবেমনির্বোধ নিজে বড় বুদ্ধিমান বিপদজনকএ বিরুদ্ধে আইন ব্যাবস্থা নেয়',
#  'কচুর লকডাউন মারা লকডাউন বড় লোক বড় সুযোগ গরীব পিশে মারা লকডাউন',
#  'কত গাড়ি চাঁপা মারে না অনেক কষ্ট',
#  'কঠোর লকডাউন',
#  'আস কোয়ারেন্টাইন ছাড়া ঘুর সবাইকে আক্রান্ত নিজে আক্রান্ত হব বাংলাদেশের করোন অবস্থা জানলে ভুলে আস চাইত না',
#  'বাঙালির দেশ ভাই অনেক হাঁট হাঁট বাড়ি',
#  'বড় ভ্যারিয়েন্ট দালাল মিডিয়ামানুষ অাতঙ্কিতভয় লাগানো ছাড়া অার নাইএদেশের গরিব মারা এসব ফাজলামিএসব কারনে উপর মহল লকডাউন কথা',
#  'খোলা লক ডাউন তামাশা ছাড়া না',
#  'লাশ দাফনে বাধা দেয় তাদেরকে কবর উচিৎ তার লাশ দাফন',
#  'দেশ লক্ষ লক্ষ অভাব আনাহারে দেশ হাজা হাজা কুটি টাকা খর মুর্তি বনায়মানবত মৃত্যু হয়',
#  'বাংলাদেশ আজব দেশ এরকম দেশ কোথা খুজে পাওয়া না পুরো বিশ্ব বাংলাদেশের চিকিৎসা সেবা নিন্নমান',
#  'ডাক্ত হাসপাতাল সরক ঘোষিত প্রণোদনা লুফে রোগী যথাযথ চিকিৎসাসেবা দেয়',
#  'হাজা চেষ্ করলে পোশাক শ্রমিক বিক্ষোভ ঠেকানো না অধিক আদায় ছাড়বে',
#  'জনগণ টাকা খর টিকা আস ইন্ডিয়া চীন বলে ঈদ উপহ যাও তামাশা',
#  'করোনাভাইরাস ক্ষতি করত তার চেয়ে বেশি ক্ষতি করত ডাক্ত ভাইরাস ওষুধ হয় নাই হয় মানুষ উল্ পাল্ ওষুধ সেবন মানুষ মার',
#  'অবাক সমস্ত রিপোর্ট একবছর করোনাভাইরাস বাংলাদেশ তারপর কিভাবে আইসিউ সংকট হয় লজ্জা হয় না',
#  'হোটেলরেস্তরাবিনোদন স্পটএ বন্ধ শিক্ষাপ্রতিস্টান খুলে দিননা ধংস',
#  'মামা বাড়ির আবদ কথা নয় কোয়ারেন্টাইন না রক্ষা যাবেনা বিষয় নমনীয়তাআর স্বজন প্রীতি দেখালে রক্ষা যাবেনা',
#  'বাল টিকা',
#  'ভুল সিদ্ধান্ত নেয়া হল সরক দায়িত্ব হীন সুস্থ্য বিধী মানাবে দেখা না বল না লকডাউনে দরক',
#  'যমুনা টেলিভিশন ফেসবুক নিয়ন্ত্রণ ভাইবোন বল আপনা মন্তব্য বাক্স বন্ধ বেশিরভাগ অশিক্ষিত নির্বোধ লোকজন আপনাদেরকে বিভ্রান্ত ক্ষমতা রাখে',
#  'পরিবহন মালিক রা ঈদ দুর্বলতা আবেগ পুঁজি দ্বিগুন তিনগুণ ভাড়া পকেট কাট চাই',
#  'মর পরিমাণ বেশ কম বাংগালীর চরিত্র কয়েক হাজা মর উচিৎ',
#  'কত বেহায়া বেশরম এরকম দুর্যোগপূর্ণ পরিস্থিতি বেফাঁস কথা বলে হয় আল্লাহ ভয় না',
#  'দুর্নীতিবাজ সরকার কোটি কোটি টাকা লুটপাট খায় ভালো সমাজে সরক চোখ তাকায় না',
#  'সবকিচু খুলে দাওসবা যেনো মার্কেট পারেবাইরে চলাফে পারেদেশের আইন কানুন না মান পারেলকডাউন কথা বললে একধরন গা জালা সরক দিলো না রে দিলো না রেকোনো দেশ এধরনে ফালতু জনগন দেখিনাইঅপেক্ষায় থাকো বাংলাদেশ ভয়বহত নির্মমতা দেখ প্রকৃতি তার আপন নিয়মে প্রতিশোধ নাব',
#  'চীন তাড়া নিজে তৈরি ভাইরাসতারা ব্যাবসা',
#  'মনগড়া খবর',
#  'লকডাউন জরুরি সচেতনতা সরক লকডাউন চালিয়ে সাধারণ লকডাউন অমান্য',
#  'মিডিয় বিরুদ্ধে মামলা কর ফাঁসির মঞ্চে হাইকোর্ট আপিল কর আসলে চায় মৃত্যু জান মাল তামাশা',
#  'স্বাস্থ্য বিধির প্রয়োজনে জরিমানা ডাবল মাক্স সহজ দ্রব্য জেল জরিম আইন',
#  'চেয়ারে অযোগ্য লোক দাপট সেখানে প্রবাসী না লকডাউন দেওয় বুজা প্রবাসি দের অন্যায়',
#  'জাতির মেরুদণ্ড শিক্ষা কেন্দ্র সেটা ভালো ধংস দিছ',
#  'পুলিশ জঘন্যতম পর্য',
#  'করোন ভয়ংকর এইসব মানুষগুলা বিপদে স্বার্থ বড়',
#  'এইসব নিউজ সম্পূর্ণ মিথ্যা ভুয়া বিএনপির সমাবেশ না সেইজন্য এইসব নাটক সাজানো',
#  'মিডিয়া বল বাটপারি ছারো তোমরা করছো বাংলাদেশের ফিটা খায়',
#  'আইনশৃঙ্খলা বাহিনীর প্রতি অনুরোধ রাস্তায় অযথা পাল উরাধোরা বাইরান দিবায়',
#  'না খায় মরে অার অারামে এসির ভিতরে বসে নাটোক মজা লও জনগন অাল্লাহ খুব তাড়াতাড়ি তোমা মজা ছুটাবে রেখো',
#  'স\u200c্যালাইন পানি টিকা বলে চালিয়ে',
#  'বড় স্বাথ',
#  'চুতিয়া দেশ আস আকুতি মিনতি ফেনা উঠিয়ে ফেলো দেশ কোয়ারাইনটে থাক বললে উল্টো যুক্তি উপস্থাপন আরম্ভ',
#  'কত অমানুষে বাচ্চা বড় বড় কথা বলে ভারত উপক করোনা ঢাল এখনো পাই না কুকু রাস্তা মরে থাকবি অহংক ভালো না',
#  'আজব কিছুতে বিদেশী উদাহারণ দেশ পরিচালন স্বার্থে বিদেশী সিস্টেম মান চল পারিনা',
#  'এসব সরকার চোখে পড়ে না',
#  'লকডাউনে পকেট ভর এমপিমন্ত্রী গরীব গরীব চল থাকলে মাংস মানুষে ছিরে খাবে',
#  'দেশীয় টিকা সরক সরকার মন্ত্রী প্রতারণা করত',
#  'চলত গনপরিবহন বন্ধ বাল প্রমাণ সরক বাংলাদেশ লক ডাউন কোথায় মানা',
#  'দেশ জনগন নিয়া সরক তামাশা',
#  'করোনা মসজিদে স্কুল ওকলেজ শপিং মলে করোনা নাই ফালতু ব্যবস্থা',
#  'দায় ভার সম্পুর্ণ সরকার ব্যর্থ ভারত আসছ করেন্টাইন বাধ্যতামূলক পারছেন না সরক',
#  'উচ্চ আদাল আপিল হয় নেগেটিভ আসবে মামু খালু তদবির পজিটিভ হলে সমস্যা নাই রাষ্ট্রপতি নাহ্',
#  'বড় ভ্যারিয়েন্ট দালাল মিডিয়ামানুষ অাতঙ্কিতভয় লাগানো ছাড়া অার নাইএদেশের গরিব মারা এসব ফাজলামিএসব কারনে উপর মহল লকডাউন কথা',
#  'করোনা মসজিদে স্কুল ওকলেজ শপিং মলে করোনা নাই ফালতু ব্যবস্থা',
#  'কুলি দিনমুজুর রিকসা চালক ভান চালক অথবা ট্রাফিক পুলিশ বাছ ড্রাইভ করোনা না চিটারি জায়গা পায়না বাটপাড়ে দিনে কতোব পায়খানা জায় সেটা খবর সুনালে জনগণ তোমার গোয়া কারেন ঝাল লাগে দিত ভাত পায়না পাগল করোনায় বাচেনা',
#  'প্রশাসন বল আপনা কঠোর হন ভারত না আস',
#  'বাম্প ফলন প্রত্যাশা কর',
#  'জনগন সার্থে পরিবহন মালিক কখনো নেয়নি দরক টাকা',
#  'সাধু সাবধান ঠকানোর পায়তা',
#  'আবারো সালা পকেট ভারি',
#  'ঘোড় ডিম ডিম বাচ্চা তার বাচ্চা বড় একদিন সেনাবাহিনী আরকি সঠিক পথে পরিচালিত',
#  'সরকারী পদক্ষেপ সম্পর্ কৌতূহলী মূল সময়ে বাংলাদেশের জনগণ একত্রিত হওয়া আল্লাহ দয়া',
#  'লকডাউন দিলে ভালো এসব আবাল মারকা লকডাউন লাভ খোলা লকডাউন ফাজলামুর সীমা দরক',
#  'ঘোড়ায় ডিম পারবে ফালতু যত্তসব নিয়ম কানুন',
#  'ব্যবস্থা ত নিত মাস যাবত কত ব্যবস্থা মরে',
#  'শয়তান দল তোরা মসজিদ মাদ্রাসা বেশি বাড়াবাড়ি করতেছিস তোদের গজব আসবে বছর যাবত শুনতে মসজিদ মাদ্রাসায় করোনা মসজিদ মাদ্রাসা আরেক কথা শুন না',
#  'আপনা মিডিয়া কত রখম আবাল মার্কা পোস্ট দয়া এরখম পোস্ট না কেননা পাবন মানসিক হাসপাতালে রোগীর সংখ্যা বৃদ্ধি পেত',
#  'মিথ্যা কথা প্রচ কিভাবে বাচ্চা করোনা কবে কবে মার গেলওযতসব নাটক হয়',
#  'টিকা দেওয় দরক নাই আল্লাহ হায়াত রাখলে এমনে বাচুম',
#  'গজব দেশ বাংলাদেশ অবৈধ স্বৈরাচারী শেখ হাসিনা অবৈধ ক্ষমতায় থাক সমস্ত অবৈধ উন্মুক্ত',
#  'এই বলে জিনিসে দাম বাড়ানো চেষ্ করবেনা',
#  'হুন্ডি টাকা পাঠা দেশ রেনিটেন্স বঞ্চিত না ভাবলে কেনো ভাববো',
#  'করোনা হয়া উচিদভা কথা করোনায় ভয় আদালত বন্দ হাজা হাজা বিচ পায়ানাএ বলে আদাল আসলে করোনা বিচ অনলাইনে কেনো করোনা হোলহেএ ঠিক করেনা',
#  'কিস বাধা মানবে সরক মাস গার্মেন্টস শ্রমিক খাওয় ব্যবস্তা পারলো না জিবন ঝুকি পেট চালা হয়লাখ লাখ শ্রমিক একসাথে একসাথে বাড়ি সমস্যা',
#  'ঈদের নামাজ পড় মসজিদে শপিংমল খোলা এগুলা মুসলমান তামাশা ছাড়া না',
#  'অফ আদালত হাট বাজা বিভিন্ন অনুষ্ঠান মাহফিল রাজনৈতিক মিটিং মিছিল ভোট হয় করোনাকালিন সময় স্কুলকলেজ শিক্ষাক্ষা করোনা খায় ফেল এই নাটক ছাড়া না বলদা মার্কা শিক্ষামন্ত্রালয় কর্মচারী',
#  'লকডাউন চায়না',
#  'ধরন লকডাউন প্রশাসন প্রতিরোধ এলাকায় মদ জুয় আসর বসা করোনা প্রতিরোধ নয়',
#  'শ্রমি পেটের ভাত মার শ্রমি নেতা রা বাসা বসে ঠিক হালুয়ারুটি খায়',
#  'সরকার করোনা বিষয়ক তথ্য আমজনত হাসি তামাশা বিষয়ে পরিণত হয় এসব তথ্য জনগণ বিশ্বাস না',
#  'বিবেক মূল্যবোধ দুটোর অভাব আজকাল',
#  'সরকার করোনা বিষয়ক তথ্য আমজনত হাসি তামাশা বিষয়ে পরিণত হয় এসব তথ্য জনগণ বিশ্বাস না',
#  'জনগণ সেবক হিসেব কথা জনগণ রাজা মত আচরণ করত ধিক্ক এইসব অমানুষ এসব অপেশ পুলিশ বিচ',
#  'রাখ ক্ষমতা পায় জুলুম ইতিহাস ক্ষমা নাই',
#  'করোনা চিকিৎসা ঔষধ সরকারি ব্যবস্থাপনায় বিনামূল্যে',
#  'সাস্থ্য খাত দুর্নীতিবাজ বহাল ততদিন ভ্যাকসিন আলোর মখ দেখবেনা কারন দেশ ভ্যাকসিন তৈরি হলে বড় খতি দুর্নীতিবাজ ডাকাত এখান থাক ভ্যাকসিন কেন নামে ডাকাতি পারবেনা অনুমোদন পাওয়া অনেক কঠিন বেপ দেশি ভ্যাকসিন',
#  'হোটেলরেস্তরাবিনোদন স্পটএ বন্ধ শিক্ষাপ্রতিস্টান খুলে দিননা ধংস',
#  'সরকার মাথা পুরো নষ্ট গেছেলকডাউন উঠা পরিবহন ছাড়েনি যতসব পাগলামি',
#  'ঈদের নামাজ একসঙ্গে পড়লে করনা ধর সম্ভবনা মার্কেট বাজরে ঘুরলে করনা ধরবেনাআল্লাহ বেশি গযব দিবে নব্য ফেরাউন দের কৃতকর্ম',
#  'সরক লকডাওন দিলে মানে না লকডাওন না দিলে প্রবলেম সাধারণ খারাপ মান না',
#  'ডাক্ত কত কসা এতে বুঝা তথাকথিত মিডিয়া ওদেরকে হিরো বানায় হায় রে',
#  'বাড়িওয়ালা পাগল গেছেন দুঃসময় অসহায় গুলো রাস্তায় নামা ওনি ভালো নাই',
#  'তারপর কেনো সরক লকডাউন শিথিল দেয় বুঝ পারছি না মানুষজন ঠেকানো পারলে লাঠিচার্জ নিজ স্বার্থ অন্য সুখ না অমানুষ',
#  'কুকুরে এতদিন ভাক্সিন ঝুলা রেখেছিল',
#  'করোনা বাংলাদেশের পালটাইনি বরং বাংলাদেশের চোর আসল চেহা বাহীর হচ বাঙা কত নিন্ম শ্রেনীর পুরো পৃথীবি দাখ',
#  'সাহে মত পাপিয় মতদেশের বেইমানী চুরি ডাকাতি জীবন যাপন কর ঠিক ছিলো যত্তসব ফাউল লোকজন',
#  'অনেক অনেক বল সীমান্ত চলাচল বন্ধ না ভয়ংকর অবস্থায় পড়ে',
#  'করোনা কবে যানিনা মন্ত্রী সাহেবের দ্রুত তার পদ ছাড় যাওয়া',
#  'হত বাংলাদেশের পতিতা টাকা চোর নেতা তার মা বোন বউ পতিত খাতায় লেখা',
#  'প্রধানমন্ত্রী বাংলাদেশ করোনা মুক্ত সহ্মম হয় লকডাউনে না বিভিন্ন জায়গায় ছড়িয়ে পরি বাংলাদেশ করোনা থাকলে সরক লকডাউন খুল না',
#  'এদেশের ভিতরে প্রকারে গেমজাম সৃষ্ মিডিয়া নামক দালাল',
#  'তারিখ স্কুল কলেজ খুল তনা খোল ধান্দা এই বুজি',
#  'দেশ ধ্বংস এইসব নবাব সন্তান',
#  'বাড়ীওলাকে এনে করোনা রুগী বেডের বাধ পশুর চায় নিকৃষ্ট',
#  'কত আক্রান্ত সচেতন সিরিয়াস আল্লাহ জানে সামনে সময় আসত ইতা ভয়ংকর রুপ নিবেআল্লাহ ছাড়া সহায়ক নাই অনুরোধ কর সরক জরুরি এখ দার কারফিউ দেনবাংগালী বুঝা ঘরে না',
#  'হ\u200c্যা আড়ং যা\u200cবো কেনাকাটা কর\u200cবো তরল খাবা খা\u200cবো ক\u200cরোনা থে\u200c নিরাপ\u200cদে থাক\u200cবোকি কথা',
#  'কিন্ত শৈরাচারি দল চাইবে তৈরি ভ্যাক্সিন লাথি মার ফাল তার বাপ বা তার স্বামীর ভ্যাক্সিন বাংলাদেশ মার্কেট পাওয়াতে',
#  'আপনা ব্যাং অনেক টাকা জমানো গরিব ব্যাং টাকা নাই খাব প্রতিষ্ঠানে চাকরি লগডাউন বানা এগারো মাস বেতন দেয়না বেতন কথা বললে লগডাউ এসব ধান্ধা বাদ্দা জনগন ভালো মারা বুদ্ধি বাদ',
#  'সরকার অবহেলা সমন্বয়হীনত কারনে করোনাভাইরাস সর্বত্রে ছড়িয়ে পড়',
#  'তাইলে এত টাকা টিকা এনে লাভ',
#  'তারিখ স্কুল কলেজ খুল তনা খোল ধান্দা এই বুজি',
#  'রোগী মুখে মাক্স নেই কেনগরু ছাগল সকুল খুলে না দেওয় তামাশা দরক নেই',
#  'তোদের মত সাংবাদিক বলে দেশ সুটিং চল ছাগল দল ছাগল শুনলে পাগল মত হাসপাতালে ছুটাছ দেয় বাংলাদেশ করোনা বল নাই গুলা মানুষিক রুগি তোরা মানুষিক চিকিৎসা দরক পাবনায়',
#  'পরিবেশ পরিস্থিতি বিবেচনায় বাংলাদেশের চাইনিজ ভ্যাকসিন উৎকৃষ্ট ভ্যাক্সিন বাংলাদেশ আন প্রয়োজন ছিলনা করোনা রাজনীতি প্রতিফলন হিসাবে এসব ঘট',
#  'হাজারের বেশি রোগী রাস্তায় গুরাগুরি পরিক্ষা হচ্ছেনা',
#  'কত আক্রান্ত সচেতন সিরিয়াস আল্লাহ জানে সামনে সময় আসত ইতা ভয়ংকর রুপ নিবেআল্লাহ ছাড়া সহায়ক নাই অনুরোধ কর সরক জরুরি এখ দার কারফিউ দেনবাংগালী বুঝা ঘরে না',
#  'গন পরিবহন চালু তার ডাবল বেশি ভাড়া আদায় ঈদে এর ভালো বসে বসে আরাম সি এনজি অটো ব্যান গাড়ি দিয়া চল থাকি',
#  'কিস বাধা মানবে সরক মাস গার্মেন্টস শ্রমিক খাওয় ব্যবস্তা পারলো না জিবন ঝুকি পেট চালা হয়লাখ লাখ শ্রমিক একসাথে একসাথে বাড়ি সমস্যা',
#  'সেনাবাহিনী নামা পিটা হাত পা ভাঙ দিক দেখি জনগন না মান কোথায়',
#  'কোরেনন্টাইন না সালাগো সিধা জাল দেয়া',
#  'ভারত বেকচিন ভালনা দুই নাম্ম',
#  'বুঝি না ফেরি কিভাবে চলাচল প্রসাশন দৃষ্ আকর্ষণ কর বাড়ি পরিবার মৃত্যুর না',
#  'ভার ভ\u200d্যাকসিন আসলে বুয়া এই হয়না',
#  'টাকা দে মাক্স টার দাম জানস হালা',
#  'মনুষ্যত্ব হীন বাচ থাকা অধিক নেই তোরা করনায় মর',
#  'সারাজীবন ভেজাল ঔষধ বানায় ঠকা ছে তোদের বিচ আল্লাহ',
#  'দুঃসময় গণস্বাস্থ্য কেন্দ্র কিট হচ্ছেতা সত্যি হিসেব লজ্জাজনক',
#  'ভারত নতুন ভাইরাস আস মার পেলা',
#  'দালাল বেক্সিমকোর অনুমদন পাচ্ছেনা গ্লোব বায়টেক',
#  'আসলে বাংলাদেশের মিডিয়া সরকার বিক্রি হয়ে সরক বলে মিডিয়া পছন্দ',
#  'কোয়ারান্টাইনে না চাইলে সিক ভিতর নাহয় জায়গায় দাঁড়া রাখুন',
#  'দূরো হালা ফোয়াভন্ডামি',
#  'কষ্ট লাঘব হলে এসব কঠোর বিধিনিষেধ নামে প্রহসন বন্ধ',
#  'বাম্প ফলন প্রত্যাশা কর',
#  'তসব আজারিইয়া খবর ধান্দা বাদ',
#  'চুরি টেকনোলজি নিশ্চয়',
#  'ঈদের আম দেশ তার জনগণ দায়ী',
#  'করোন সঠিক মূল্যায়ন কর দরজা খুলে বাহিরে যাওয়া দুর কথা জানালা খুলে বাহিরে তাকানোর সাহস পেত না',
#  'শিক্ষা মন্ত্রণালয় সকল কার্যক্রম স্থগিত বলদা মার্কা দুই মন্ত্রীরে অবসরে পাঠানো',
#  'স্বাস্থ্য মন্ত্রীসহ স্বাস্থ্য মন্ত্রনালয় প্রত্যেক কর্মকর্তা কর্মচারী দ্বায়িত্বে ফাকি দেয়া ছিলো নিত্য দিন ব্য নার্স স্টাফ ওয়ার্ড বয় ডাক্তাররাসহ মারাক্তক গাফিলতি বল অপেক্ষা রাখে না স্বাস্থ্য মন্ত্রী পদত্যাগ সহ স্বাস্থ্য মন্ত্রনালয় নতুন ঢাল সাজানো অতি জরুরী পর',
#  'অনেক অনেক বল সীমান্ত চলাচল বন্ধ না ভয়ংকর অবস্থায় পড়ে',
#  'মারা পোলো',
#  'কিস বাধা মানবে সরক মাস গার্মেন্টস শ্রমিক খাওয় ব্যবস্তা পারলো না জিবন ঝুকি পেট চালা হয়লাখ লাখ শ্রমিক একসাথে একসাথে বাড়ি সমস্যা',
#  'কাঁচ ঘরে বসে আমা রাস্তায় মন্ত্রী রাস্তায় নামুন না সবাইকে ঘরে বসে থাক বলুনখ পাচা টাকা এনে বাঁচানোর চেষ্',
#  'সরকার উদাসীনতা বর্বর জনগন জনগন',
#  'বিবেক হীন দের আল্লাহ পাক যথেষ্ঠ',
#  'দরবারে পাগল খেলা সব প্রধানমন্ত্রী শেখ হাসিনা নেওয়া দরকারতারপরে সাধারণ জনগণ পাগল ছাগল দল',
#  'কঠর রিক্সা দিনমজুর অসহায় সাধারন পাবলিক উপরধান্দা পুলিশ সেখানে',
#  'গুলোর অবস্থা বাংলাদেশ বাংলাদেশকে গালি দেয় ভয়ানক পরিস্থিতির ফেল দিল',
#  'খাইয়া নাই ক্যান করোনা অবস্থা খারাপ মার্কেট নিয়া ব্যস্ত হ্লা বাঙা হইবি না তর মরলে হবি বুজ',
#  'টিভি করোনা উপসর্গ মৃত্যুর সংখ্যা বেশি আপনা হিসেব কম মার কিভাবে',
#  'সময় টিভির সাংবাদিক হাত দড়ি বেঁধে দেয়া মুখে কসটেপ অথবা সুপ গ্লু লাগিয়ে দেয়া আজেবাজে নিউজ প্রচ না',
#  'সকল ফালতু খবর ছড়িয়ে মানুষ বিভ্রান্ত চেষ্',
#  'বেশী ভাগ চেয়ারম্যান মেম্ব চোরচাপ্ ঝাপ্ মুর্খ বিবেকহী পশু না মহামারীর সময়',
#  'নাও যত খুশি করোনা যাও বেশি বেশি বাইরে যাও',
#  'ভারত ভ্যাকসিন নিষিদ্ধ ঘোষণা',
#  'ফালতু নিউজ বন্ধ ভয় সৃষ্',
#  'গণপরিবহন চালু বাল লকডাউন ভোগান্তি ছাড়া না টাকা ভাড়া টাকা রিকশায় অফ',
#  'মিথ্যাবাদি করোনায় ধ্বংস হউক',
#  'অপদার্থ সরক জানেনা পাবলিক মানবে মানবে না',
#  'বাংলাদেশ ভ্যাকসিন আস দুই মাশ সৌদি আর ভ্যাকসিন পায়ছেসৌদি আরবে যাদের ভ্যাকছিন হয় কোরোনায় আক্রান্ত হলোনাআর বাংলাদেশ ভ্যাকছিন দেওয় কোরোনায় আক্রান্ত হয়ভারত ভ্যাকছিন আনাহ ভুয়াসাংবাদিক রাও বরো করম চোদসরক শিখা দেয় শালা বলে',
#  'লকডাউন ভেতোর বাইরে ভাবেসরক দেশ বাজে লকডাউন গরীব মানুষ না খাওয়া মার',
#  'স্বাস্থ্য মন্ত্রণালয় এতটুকু নিশ্চিত না পারলে হাসপাতাল করোনা চিকিৎসা',
#  'সরক লকডাউন বন্ধ না গরীব খাবারের ব্যাবস্থ লকডাউন দেক',
#  'বেপরোয়া রাস্তায় নামলে বোঝা নিয়ম ভাঙা তীব্র প্রতিযোগিতা করোনাকালীন পরিস্থিতি স্বাস্থ্য বিধি না মানা চূড়ান্ত অনীহা',
#  'ঘোষ না দিলে সরক ভ্যাক্সিন চল দিবেনা',
#  'কথায় কথায় কমি গঠন যেদিন কমি গঠন এদেশ বিতাড়িত সেইদিন সোন বাংলা',
#  'সরক বাচানোর লকড়াউন নায়এ লকড়াউন পিছনে বড় মাফিয়া হাত করোন পিছনে অনেক লুকা',
#  'সরক কখন জনগণ ভালো চায় না চাইতো ঐই রমজান ভিতরে লকডাউন দিত সময় খুলে দিল জেলা জেলায় ছুটাছু',
#  'কঠোরতা নয় অমানুষ পরিচয় দেয় পুলিশ',
#  'সরক ট্রায়াল অনুমতি দেয় না এখান সরক দূর্নীতি পারবে না অনুমতি নাই',
#  'মিলে জুলুম বেক দেখ মার রেমিট্যান্স অভাবে সরক জনগণ খাবেজনগণ সরক খাবে',
#  'পুলিশ সম্পূর্ণ বেপরোয়া সন্ত্রাসী মনোভাব প্রদর্শন সমাজ আতংক পুলিশ',
#  'বাংলাদেশ চল ফাঁকা বুলি বলদ জনতা ঘুম পাড়ানো মুলত প্রবাসী শ্রমিকেরা বিদেশ মহামারীর সময় মানবেতর জীবনযাপন',
#  'সরকারি বেতনভুক্ত দালাল',
#  'হাইস্যকর সরকার কাম স্বার্থ উদ্ধ হই আস আস খুলে দিবে করোনা পালাইবে',
#  'সরকার অবহেলা সমন্বয়হীনত কারনে করোনাভাইরাস সর্বত্রে ছড়িয়ে পড়',
#  'কুমিল্লা শহর সহ আশে পাশ মার্কেট বন্ধ কুমিল্লা ক্যান্টনমেন্ট মার্কেট খোলা সেনাবাহিনীর অধীনে ভালো ভালো নাহ',
#  'লক্ ডাউন কাক বলে বুজ না সব হিয়ালীপনা স্বাস্থ্য স্বরাস্ট্র সসশ্রবাহীনির হাত দিত দিনে পুর নিয়ন্ত্রন ত্রান টাইৃ নস্ট',
#  'লওউ ঠ্যালা পুলিশ এমনিতে জাহেল পেলো দালা সুযোগ',
#  'মরলে মর ভাংগা হাসপাতাল কিলিনিক মরে যাবকিনতু সবাইকে নিয়েভা দের জার করোন রুগি জড়ি ধরবে মক হাসি দিব',
#  'সরকার নেতাকর্মি এত গরিব হয় সাহায্য করতে বাংলাদেশ কয়েক বার বিক্রি',
#  'গবেষণা ভুয়াএর প্রমাণ কমেন্টগুলোআর করোনা তার শরীরে ভাইরাস থাকেনা অন্য আক্রান্ত না ভরসা দেশ পরিচালনা দেশদেশ না',
#  'কিন্ডারগার্টেন মানে ব্যবসা প্রতিষ্ঠান শিক্ষা ব্যবস্থা নস্ট কিন্ডারগার্টেন দায়ী',
#  'দুর্নীতিবাজ অযোগ্য পাপন গ্যাং বাহিনী পরাজিত সিরিজ ভুয়াটাইগাররা হারলে ভয় দিন কোয়ারেন্টিন দিনে করাইয়া ফেল',
#  'কাহিনী চলবে না আটকা রাখেনতানাহলে ভারত অবস্থা খারাপ',
#  'হোটেল না থাক চাইলে কারাগারে পাঠানো দরক ইটা পেরত যাত্রী গালি নিজ দেশ অপমান তার গন স্বাস্থ্য হুমকির মুখে পাল সরকার অনুরোধ ভুল যাবেনা এসব যাত্রী হোটেল না থাক চাইলে কারাগারে পাঠানো হক',
#  'প্রভাব শালি লোক অপরাধ অগ্রিম জামিন রাখে করনা জামিন',
#  'সাস্থ\u200c্য বিভা\u200cগ চোর গু\u200cলে প\u200cরি\u200cস্থি\u200cতি',
#  'বাহির আনলে মন্ত্রী পকেট একটু ভরপুর টিকা অনুমোদন পাবেনা কখনো নাহ',
#  'ভন্ডামি কেবল বাংলাদেশ সম্ভব',
#  'বড় কোম্পানি অবশ্য এসব নাতা মাঠ পযার্য় সকল নাও করোনা পারবেনা মাস শাষ কোম্পানি বেতন দেয়তা এসকল কোম্পানির মালিক পা চাটা কুকু মিলে সাধারণ অল্প বেতন মানুষ বাধ্য দেশ করোন বিস্ত ঘট সাহায্য টিভি বার বার না বলেপারলে সকল শিক্ষত বড় দের থামা নাহলে মহামারি দেশ জাতী বাচানো যাবেনা',
#  'জনগন সরক লকডাউন বিরুদ্ধে বিক্ষোভ মিছিল উচিৎ না পরিণামে দেশ দুর্ভিক্ষে পতিত',
#  'আসলে বাংলাদেশের মিডিয়া সরকার বিক্রি হয়ে সরক বলে মিডিয়া পছন্দ',
#  'সমস্ত অমানুষ জায়গায় অনেক জায়গায় প্রভাব বিস্ত অনেক জায়গায় না আসলে কতটুকু সভ্য সমাজে বাস করোনা ভাইরাস আবির্ভাব ভাল অনুধাবন পেরেছি মরনশীল হীন কাজ কর আল্লাহ না আত্নীয় করোনায় আক্রান্ত মার পারত',
#  'হসপিটাল বোমা মার উড়া',
#  'বাংলাদেশ আজব দেশ এরকম দেশ কোথা খুজে পাওয়া না পুরো বিশ্ব বাংলাদেশের চিকিৎসা সেবা নিন্নমান',
#  'লকডাউন চোদা পাট ভাত নেই চিকিৎসা নেই তোমা মত কোটি টাকা লুট ঘর ভোরে খাবা কিনে বসে নেই',
#  'প্রশাসন বল আপনা কঠোর হন ভারত না আস',
#  'এইসব চেয়ারম্যান করেনা রুগীর দরক',
#  'গ্লোববায়োটেক ভ্যাক্সিন তৈরি চামচা খাবে',
#  'নৃশংস ডাক্ত নাম শশু ওনা মত মহান মন শিক্ষা নেয়া দরক বিপ সময় ছার পালা বেড়ায়যা টাকা জন\u200d্য ডাক্তারি',
#  'টাকা প্রাপক পাবে না চোর দল খেয়ে ফেলবে',
#  'খুব সীগ্র সাধারণ পুলিশ গা হাত তুল বাদ্য কারন পুলিশ অাজকাল সীমা অতিক্রম কর',
#  'হাজারের বেশি রোগী রাস্তায় গুরাগুরি পরিক্ষা হচ্ছেনা',
#  'সময় নিউজ প্রতিদিন বার ভ্যাক্সিন আবিষ্ক সেটা বিশ্ব সাস্থ্য সংস্থা জানে না',
#  'গতকাল ডাক্ত হেনস্তা করলো সাধারণ পথযাত্রী জুলুম শেষ কোথায়',
#  'করোনা মসজিদে স্কুল ওকলেজ শপিং মলে করোনা নাই ফালতু ব্যবস্থা',
#  'সাধারণ মানুষ লক ডাউন নামে কষ্ট ধরণ নাটক তীব্র নিন্দা',
#  'মেরুদণ্ডহীন মন্ত্রীর লজ্জা সরম বল গত বছর ডেংগু মহামারি পদত্যাগ করতএক অপদার্থ',
#  'সালা দালাল তাদের',
# ...
#  'এসব লকডাউন দেওয় মানে হয়না',
#  'মিডিয়া বল বাটপারি ছারো তোমরা করছো বাংলাদেশের ফিটা খায়',
#  'করোনা চিকিৎসা ঔষধ সরকারি ব্যবস্থাপনায় বিনামূল্যে',
#  'সীমিত আকারে চলাফে করোনা সীমা ছাড়া সাহায্য প্রতিনিয়ত',
#  'এইদেশ অনেক করোনায় আক্রান্ত নিরাপত্ত বাড়িওয়ালাকে দেশ বের',
#  'বর্তমান প্রেক্ষাপটে স্বাস্থ্যসেবা ঢাল সাজা স্বাস্থ্যমন্ত্রীর পদত্যাগ অবশ্য জরুরিকারন করোন মহামারীর বছর বেশি সময় পার হলে তার সাফল্য জিরো হলে দুর্নীতি হিরো হয়েছেন',
#  'মনুষ্যত্ব হীন বাচ থাকা অধিক নেই তোরা করনায় মর',
#  'দেশ গুণীর সমাদর নাইসে দেশ গুণী জন্মা নাআর হল চোর জাতী গুণী লোক কথা বুঝিনা',
#  'মহামারীর টাইমে কিভাবে ভারতীয় লোকজন ভিসা হল চক্রান্ত কিনা খতিয়ে অতি মানবিক ভালো নয়',
#  'কোরোনা চাইতে শক্তিশালী',
#  'করোনা সমস্যা নাইসমস্যা অবস্থাব্যবস্থা দেশ',
#  'মু\u200cখে আ\u200cসে ব\u200c টেস্ট বেশী ক্ষমতা হই\u200cলো না',
#  'কারণে লকডাউন লকডাউনে করোনা সংক্রমণ কমে কখন না লকডাউন মানে বন্ধ দেশ লকডাউন মানে ধনীর আয় চাকা সচল সাধারণ নিম্ন আয় পথ বন্ধ ধরন লকডাউন সেটা মাথায় আসল না',
#  'গন পরিবহন চালু কেঊ বলে নাইপ্রাইভেট গাড়ি কেনো চালু হল সেটা চায়বন্ধ থাকলে বন্ধ',
#  'অবৈধ সরক লকডাউন রাজনৈতিক হাতিয় হিসেব',
#  'তোমা পাবনায় পাটালে পাবন মান সমমান ধুলো মিশে এসব গাজাকরু খবর মানুষ বিপদে ফেলবেনা',
#  'পৃথিবীর সকল রাষ্ট্র হয়ে চীন বিরুদ্ধে অ্যাকশনে লক্ষ নিহত হয়ে',
#  'সীমান্ত সম্পূর্ণ বন্ধ যানবাহন',
#  'মেরুদণ্ডহীন মন্ত্রীর লজ্জা সরম বল গত বছর ডেংগু মহামারি পদত্যাগ করতএক অপদার্থ',
#  'মহামারীর টাইমে কিভাবে ভারতীয় লোকজন ভিসা হল চক্রান্ত কিনা খতিয়ে অতি মানবিক ভালো নয়',
#  'বাংলাদেশের এইসব গল্প শুন শুন ভালো লাগেনা রেপ পুলিশ সেনাবাহিনীর বাহিনী',
#  'আপনা মত সাৎবাদিক আতংকিত',
#  'অনেক সহজে টিকা ছাড়া সকল করোনা ভাইরাস কয়েক মিনিট ভেতর নিস্ক্রিয় সকল মিডিয়া সেটা ব্যপারে কথা বলেনা এদেশের ঔষধ ব্যবসায়ী নিয়ন্ত্রিত সহজ পদ্ধতির কথা বললে অকাল কুস্মান্ডোর হাসি পায় না ভুয়া বলে কারন দৌড়',
#  'এখন লকডাউন ছাড়বে লকডাউন দিয়েছি আন্দোলন বন্ধ সাধারণ পাট লাথি মারা',
#  'বিশেষজ্ঞ সালা সবচাইতে খারাপ',
#  'করোন ভুয়া রিপোর্ট ডাক্তার ব্যবসা ছাড়া নেই লকডাউন',
#  'বেপরোয়া রাস্তায় নামলে বোঝা নিয়ম ভাঙা তীব্র প্রতিযোগিতা করোনাকালীন পরিস্থিতি স্বাস্থ্য বিধি না মানা চূড়ান্ত অনীহা',
#  'বুঝ না সাহায্য তার বেশির ভাগ ব্যাক্তিগত উদ্যোগে সরকারী সাহায্য অনুদান কোথায়',
#  'করোনা চিকিৎসা ঔষধ সরকারি ব্যবস্থাপনায় বিনামূল্যে',
#  'আম অবস্থা খারাপ মুল কারন হল জজ্ঞ নেত গাজাখুড়ি নেত কারনে সাধারন জিবন ঝুকি কারন টাকা উপারজন পরিব চালা বাছ জজ্ঞ নেত অভাবে দেশ রসাতলে জাবে বা আসবে না ত মত রাজা হালে কার হল',
#  'ধরন লকডাউন তামাশা না',
#  'মর পরিমাণ বেশ কম বাংগালীর চরিত্র কয়েক হাজা মর উচিৎ',
#  'সমাজে শিক্ষিত বলদ পর উপকারে না বরং অন্য ভালো কিছুতে এলার্জি সমালোচনা ছাড়া কাজে না',
#  'মেয়াদ উত্তির্ন দুই পোটলা গাঁজা',
#  'হসপিটাল লোকজন তদন্ত কমি বোক স্বর্গে বাস করায় সমান কতা এই পরিকল্পিত',
#  'দেশি ভ্যাক্সিন তৈরি এদেশের চোর চুরি একটু কঠিন এজন্য অনেক উদ্ভাবন আলোর মুখ দেখেনি ভ্যাক্সিন চোর দাপটে অন্ধকারে রয়',
#  'লকডাউন মানিনা গনআন্দোলন গড়েতুলোন',
#  'পাবলিক বিশ্ববিদ্যালয় জাতীয় বিশ্ববিদ্যালয় শিক্ষার্থী সেশন জট বাড়তে থাকুক পড়ালেখ দরক নাই',
#  'না খায় মরে অার অারামে এসির ভিতরে বসে নাটোক মজা লও জনগন অাল্লাহ খুব তাড়াতাড়ি তোমা মজা ছুটাবে রেখো',
#  'বাংলাদেশ চিকিৎসা ব্যবস্থা খারাপ বর্তমানে দুর্যোগ না বুঝতাম না দেশ অনেক পেছনে',
#  'দায়িত্বে আছ সবাইকে বল আপনা আল্লাহ কখনো ক্ষমা না না নাহে আল্লাহ সবাইকে হেদায়েত দান আমীন',
#  'রোগি আহ্বান জানাবো হাসপাতালে ভাংচুর প্রয়োজনে আগুন লাগা দরক ভিআইপিরা পাবে বাকি জনগন না',
#  'পরিবহন শ্রমিক খারাপ স্বাস্থ্যবিধি মান না টাকা টাকা জীবন না ব্যবহ খারাপ স্বাস্থ্যবিধি মান চল বালা নেই গণপরিবহন বন্ধ থাকুক লকডাউন অনেকদিন চলুক সংশোধিত না হওয়া পরিবহন বন্ধ',
#  'সাংবাদিক মিথ্যা নিউজ',
#  'সরক অনুদান দেয় কার পায় অনুদান টাকা না পকেট ডুক',
#  'সরক সংবাদ দেখেনাকি ঘুমায়',
#  'মিডিয়া চরম অকৃতজ্ঞ বড় অর্জন অথচ হাইপপ্রচ নাই',
#  'গণপরিবহন চালু বাল লকডাউন ভোগান্তি ছাড়া না টাকা ভাড়া টাকা রিকশায় অফ',
#  'তোমা পাবনায় পাটালে পাবন মান সমমান ধুলো মিশে এসব গাজাকরু খবর মানুষ বিপদে ফেলবেনা',
#  'বাট রাষ্ট্র আইসোলেশন কই বসুন্ধর আশায় থাকব',
#  'স্বাস্থ্য খাত দুর্নীতির মহাসাগরে পতিত',
#  'স্বাস্থ্য অধিদপ্তর চোর মানবদেহ ভ্যাকসিন প্রয়োগ অনুমোদন মিলবে না দেশীয় জিন মূল্যায়ন না বিদেশ আনলে লাভ টাকা চুরি পারবে এইজন্য',
#  'বাংলাদেশের পুলিশ শুয়োর বাচ্চ চুদায় না পুলিশ চাকরি মাদারচোদে পুলিশ প্রকাশ্য সন্ত্রাসীর',
#  'সরক দোষ লাভ নাইসরক দিচ্ছেসরকারি কর্মকর্তা আর্ধেক খায় আর্ধেক ভাগাভাগি জনগণ দেয় কর্মকর্তা চামচা খাচ্ছেবন্তন আসলে সঠিক না বা চেষ্ করত না',
#  'পুলিশ আশা না দল দালা জনগন জানমাল লুণ্ঠন',
#  'কথা ছোট ছোট না বাংলাদেশ উন্নয়ন রোল মডেল অর্থনৈতিক কার চাইতে ভাল অবস্থানে বাংলাদেশ কত মাস সরক সার্বিক খরচ চালা পারবেনা এসব শুধু আওয়াজ',
#  'মন্ত্রী মহোদয়গণ হসপিটালে ব্যাড পায় ভ্যান্টিলেটর পায় করোন টেষ্ট সাধারণ ঘন্ ঘন্ দিন এভাবে লাইনে দাড়া থাক',
#  'করোনা মহামারী আক ধারন সাবধান হওয়া',
#  'অতিরিক্ত ভাড়া জরিমানা',
#  'শিল্পপতি ব্যাংক ঋণ মওকুফ শিক্ষ মন্ত্রী এমপি সরকার মাথা ব্যাথা নেই',
#  'এখনো সময় চিন বিরুদ্ধে বিশ্ব নাহলে সার বিশ্ব চিন হুমকি দাড়াবে',
#  'ওনা রোগীর আস সময় কোথায় ওনারা আছ হসপিটাল গেইটে অপেক্ষারত রোগী সুস্থ হাত তালি বিদায় জানানোর',
#  'খুব সীগ্র সাধারণ পুলিশ গা হাত তুল বাদ্য কারন পুলিশ অাজকাল সীমা অতিক্রম কর',
#  'দেশটারে লুই পুই খাবা তোমরা জনগণ দেখ দায়িত্ব বড়লোক',
#  'স্থানে করুনা নাই শুদু মসজিদ করুনা না ব্যাং এত যেম গোলা না',
#  'সালা মাগিবাজি হাজা হাজা টাকা খরচ অথচো গরিব পাশে দারা পারেনা হায়রে পশুর খারাপ',
#  'স্বাস্থ্য মন্ত্রণালয় এতটুকু নিশ্চিত না পারলে হাসপাতাল করোনা চিকিৎসা',
#  'গন পরিবহন বন্ধো কারন পরিবহন শ্রমিক শরিরে চর্বি একটু বাড়',
#  'হসপিটাল লোকজন তদন্ত কমি বোক স্বর্গে বাস করায় সমান কতা এই পরিকল্পিত',
#  'ফাইজলামি জায়গা পায়না এতদিন বলে ভ্যাকসিন নিলে করুণা উড়ে বলে ভ্যাকসিন নিলে সমাধান হবেনা হাস্যকর না পাবলিক বুঝে',
#  'সরকার উদাসীনতা বর্বর জনগন জনগন',
#  'বাংলাদেশ নিজেরা মুল্যে নাশুধু জানে দুর্নীতি',
#  'বাংলাদেশ চল ফাঁকা বুলি বলদ জনতা ঘুম পাড়ানো মুলত প্রবাসী শ্রমিকেরা বিদেশ মহামারীর সময় মানবেতর জীবনযাপন',
#  'সব পাগলামি ছার না বলে আরক বার বলে গাঁজা খায় কথা বলে ডিসিশন এত সমস্যা',
#  'সরক ফটকাবাজ প্রমাণ করলো দুই দিন রিপোর্ট আজক রিপোর্ট প্রমাণ নমুনা দেশ চোর সরক এইভাবেই',
#  'না খায় মরে অার অারামে এসির ভিতরে বসে নাটোক মজা লও জনগন অাল্লাহ খুব তাড়াতাড়ি তোমা মজা ছুটাবে রেখো',
#  'মু\u200cখে আ\u200cসে ব\u200c টেস্ট বেশী ক্ষমতা হই\u200cলো না',
#  'পুলিশ বিরুদ্ধে গণআন্দোলন গড়ে তোলা দিনদিন চরম বেয়াদব',
#  'উচ্চ পর্যায় দায়িত্বশীল জায়গা অদক্ষ অশিক্ষিত মূর্খ বর্বর বসানো হয় দেশ মানবতা বিবেচনা বল না পৃথিবীর একমাত্র দেশ বাংলাদেশ ধনী সবকিছু ওপ রকম অবস্থা গরীব হয় সবসময় অবিচ অত্য ধিক্ক আইন এদেশের নিয়ম',
#  'গরুর মুত',
#  'আপনা মিডিয়া কত রখম আবাল মার্কা পোস্ট দয়া এরখম পোস্ট না কেননা পাবন মানসিক হাসপাতালে রোগীর সংখ্যা বৃদ্ধি পেত',
#  'ঈদের আম দেশ তার জনগণ দায়ী',
#  'ফালতু মন্ত্রী',
#  'মর শালা তোদের কপালে কারন তোরা উন্নয়নশীল বাংলাদেশের নাগরিক অনেক দুঃখ কথা বল সময় টাকা ফুর্তি মার আল্লাহ রক্ষা',
#  'ভারত ভ্যাকসিন নূন্যতম কার্যকারিতা নাই',
#  'সরকারি হাসপাতাল বেহাল দশা সরক অনুদান হাসপাতাল চোরে লুটপাট খান পেট বোরে শেখ হাসিন গরিব সরক দাবি জনগন মানিনা মিডিয়া দুর্নীতি প্রোচ বাংলাদেশের দুর্নীতি থামবে কবে দুর্নীতি সরকার পতি সেক্টরে বাড় দুর্নীতি করোনা কালিন সময়',
#  'দুয়া আল্লাহর আজাব সুট বড় সব হলে দুনির তোরা ডুর বিতর আসবে দুনিয় পশুর খারাপ',
#  'বাংলাদেশের ভাইরাস আস সরকার ভুল সিদ্ধান্ত কারণে ইটা সব সরকার ইটালির ফ্লাইট গুলা বন্ধ',
#  'লজ্জা শরম বড্ড অভাবজ্ঞান বুদ্ধি থাকলে নির্বোধ শপিং মারাইতো না',
#  'রোজা শেষ গালি অসুবিধা নেই উল্ পাল্ আতংকিত মার্কা খবর প্রচ গালি দেয়া কর',
#  'বছর ইদ বাবা মার কাটা না পারলে দরক নেই লকডাউন',
#  'বাংলাদেশের ডক্টর সুদো ব্যাবসা জানে সেবা জানেনা',
#  'সম্পুর্ণ বাংলাদেশ সরকার গাফেলতি',
#  'ঈদের সময় অন্তত স্বাস্থ্যবিধি মান গণপরিবহন চালু প্রয়োজন লকডাউন কমি আক্কেল জ্ঞান নেই চক্রান্ত চল বাংলাদেশ ভাইরাস বৃদ্ধির',
#  'গণপরিবহন চালু বাল লকডাউন ভোগান্তি ছাড়া না টাকা ভাড়া টাকা রিকশায় অফ',
#  'বিরক্তিকর আচরণ',
#  'মৃত্যুর মিছিল থামবে না বেইমান বেইমান মিডিয়া',
#  'লকডাউন দিলে ভালো এসব আবাল মারকা লকডাউন লাভ খোলা লকডাউন ফাজলামুর সীমা দরক',
#  'আবাল প্রথমে নিয়া ট্রল আসলে বাংলাদেশী',
#  'ডিম থেরাপি ভার ফেরত পাঠা উচিৎ',
#  'সৌদি মাএ হয়েছিল কত নিয়ম চালু করছেক কঠোর ব্যবস্থা নেওয়া হয় বাংলাদেশের হাজারো বেশি ব্যবস্থা নেই নমুনা সংগ্রহ বন্ধ না হয় অনেক কঠোর ব্যবস্থা নেওয়া',
#  'টাকা দে মাক্স টার দাম জানস হালা',
#  'কোষ্টগার্ড জাহাজ গুলিকরে ডুবা দেয়া হউক',
#  'ডিপ্লোমা পড়ুয়া স্বাস্থ্যবিধী না মান পরিক্ষা হচ্ছেসংক্রমন বাড়বে',
#  'প্রবাসী খেলা বন্ধ',
#  'সাস্থ\u200c্য বিভা\u200cগ চোর গু\u200cলে প\u200cরি\u200cস্থি\u200cতি',
#  'লকডাউন চায়না',
#  'সীমিত আকারে চলাফে করোনা সীমা ছাড়া সাহায্য প্রতিনিয়ত',
#  'করোনা পুজি সুবিধা ভোগী সুবিধা ব্যাস্ত',
#  'তাইলে বাল টিকা দিয়া লাভ কিকরনা নয় আল্লাহ ভয়করি',
#  'বিশ্ব দেশ রেমডেসিভির করোনা চিকিৎস কার্যকর ওষুধ হিসাবে প্রমাণ পাই নাই স্বীকৃতি নাই টাকা হাতা নিতে এসব অপকৌশল',
#  'ভারত অবস্থা শিক্ষা না হয় বাংলাদেশের অবস্থা শোচনীয় যেভাবে ঈদের কেনাকাটা চল বিপদ ডেক আনা',
#  'পুলিশ পদক্ষেপ ভুল কোথা জটলা না সেটা না জনে জনে চেক এরা পুলিশ সপ্তাহ লকডাউন পার্থক্য বোঝে না',
#  'খোদ গজব পরুক এসব পুলিশ গরিব পাট লাথি মারে',
#  'চায়না ওষুধ আবিষ্ক নাই বাংলাদেশ বাল করবো চায়না বাংলাদেশ আসতা আলাদা থাকা জায়গা তৈরী কম হয়লে জানি মাস জানি ছাড় না পরিবার সদস্য আসতাছ আপনা বুঝে বাসায় যাইয়েনআপন পরিবার সদস্য জানি সমস্যা না সতর্ক',
#  'করোনা না থাকলে জানতে পারতাম না সকল মানসিক অসুস্থ বসবাস',
#  'বাংলা চিকিৎসা ব্যবস্থা খারাপ জার রোগী দের আছরন আল্লাহর গজব পড়বে জার সৌদি আর থাকি খানে রোগী আদর চিকিৎসা',
#  'এরে জুতা খাওয়ানো',
#  'ভার ভ\u200d্যাকসিন আসলে বুয়া এই হয়না',
#  'দেশ লকডাউন চালু থাকলে মাঝে চাহিদা পূরণ সরক ব্যার্থ সরকার ইমেজ আাঘাত হানবে ভাব সরক দূরভিক্ষ ভয় লকডাউন শিথিল কর',
#  'হয় লক ডাউন রাখুক না হয় খুলে দিক খাট খাওয়া মানুষ কত কষ্ট দিবে সরক',
#  'স্কুল কলেজ না খোল নতুন ষড়যন্ত্র',
#  'কষ্ট লাঘব হলে এসব কঠোর বিধিনিষেধ নামে প্রহসন বন্ধ',
#  'একা আক্রান্ত বাড়ির এল মানুষ সংক্রামিত শান্তি পাবে',
#  'ওমান দেশ আমা বাসায় রোমে কোওয়ারেন্টেন নিয়ম দিছ দেশ ধান্দা রাস্তা খুল',
#  'সিংগাপুরে আমেরিকারে ঋণ পোন্দা না লকডাউন খোল',
#  'ব্যাপক বিনোদন শালা মালু না থাকলে অনেক বিনোদন বঞ্চিত হতাম',
#  'সরক বেক বসে বসে লকডাউন গরিব ভাত মার',
#  'ফেরিঘাট সিএনজি গাড়ি চালু কৌশলে বল মানে হয় না খালি নাটক',
#  'ওষুধ না বিভিন্ন ওষুধ কোম্পানি আলা ফেসবু স্ট্যাটাস দেয় বিরুদ্ধে ব্যবস্থা নেওয়া অন্যথায় অনেক ক্ষতিকর মুখে',
#  'লকডাউনে পকেট ভর এমপিমন্ত্রী গরীব গরীব চল থাকলে মাংস মানুষে ছিরে খাবে',
#  'চলত গনপরিবহন বন্ধ বাল প্রমাণ সরক বাংলাদেশ লক ডাউন কোথায় মানা',
#  'একেবারে ভুয়া খবরআম মত অনে টিকা দিয়েছেনসকল ভালসমাজে বলদ তিল তাল বানায়ওরা হল আসল রাজাকারওদেরকে ফাঁশি দেশ রাজা মুক্ত হউক',
#  'ছাড় নয় আইন মানতে যেই',
#  'অবাক হওয় নাইবরং রোগি কম অবাক হইতাম যেই মার্কেট যাইত',
#  'অষ্টেলিয় মত না মানলে জেল',
#  'জনগন সার্থে পরিবহন মালিক কখনো নেয়নি দরক টাকা',
#  'সরকারী মন্ত্রী কুত্তা অর্থ লুটে খায় অথচো জনগণ না খায় মার অাম্লীক নামক শয়তান মুক্তি চায় দেশ',
#  'বাড়িওয় সাহায্য সহযোগিতা সুচিকিৎস ব্যবস্থা সহানুভূতি না ঘর বের অমানবিক',
#  'পৃথিবীর সবচ অশিক্ষিত মুর্খ বর্বর জাতী ইন্ডিয়ান রা',
#  'সরকার মাথা পুরো নষ্ট গেছেলকডাউন উঠা পরিবহন ছাড়েনি যতসব পাগলামি',
#  'ফাকা বুলি শুনা শুনা দেশ টাক আসহায় বানা ফেল',
#  'লও টেলাকরোনা জাল ঢোকা রিমান্ড ভয় দেখিয়েপাচ লাখ নাওহাহা',
#  'অথচ সরক বাংলাদেশের টিকা বংগভ্যাক্স অনুমোদন পারেনা ভারত ভিক্ষা নেওয় অপেক্ষায় এত বাশ খায় শিক্ষা না',
#  'লক ডাউনে খাওয়া লাগে নাই কারফিউ লাগা করোনা চইলা না কারফিউ দিয়া সবকিছু বন্ধ কইরা রাখ',
#  'এই বাংলাদেশ জিবন মুল্য নেই দেশ',
#  'বাঙা বাংলাদেশি হয় অপপ্রচ হেসেছেন ব্যঙ্গ হাসিতা গালে জুতা মার ★ বায়োটেকের জন্ম ইউরোপে হওয়া ছিলো বাঙা বাংলাদেশি নাগরিক হিসাবে গর্ব বোধ কর ★★এখন অনেক নামক চাটুক তেলবাজ বায়োটেকের লেবেল লাগা বড় বড় কথা বলবে',
#  'চিকিৎসা না বন্ধুর রাষ্ট্র সাহায্য করত',
#  'সিএনজি চড়লে সমস্যা নাই বাসে স্বাস্হ্যবিধি মান ডাবল সিটে বসলে করোনায় ধরে…',
#  'সমাজে শিক্ষিত বলদ পর উপকারে না বরং অন্য ভালো কিছুতে এলার্জি সমালোচনা ছাড়া কাজে না',
#  'নিয়ম মারি',
#  'দুনিয়ায় খোলা শুধুমাত্র শিক্ষা প্রতিষ্ঠান বন্ধ তামাশা ছাড়া',
#  'পুলিশ বিরুদ্ধে গণআন্দোলন গড়ে তোলা দিনদিন চরম বেয়াদব',
#  'দুনিয়ায় খোলা শুধুমাত্র শিক্ষা প্রতিষ্ঠান বন্ধ তামাশা ছাড়া',
#  'মৃত্যুর মিছিল থামবে না বেইমান বেইমান মিডিয়া',
#  'করোনা বাংলাদেশের পালটাইনি বরং বাংলাদেশের চোর আসল চেহা বাহীর হচ বাঙা কত নিন্ম শ্রেনীর পুরো পৃথীবি দাখ',
#  'কঠর রিক্সা দিনমজুর অসহায় সাধারন পাবলিক উপরধান্দা পুলিশ সেখানে',
#  'দেশ প্রবেশের অনুমতি তাদের সর্বোচ্চ শাস্তির আওতায় আনা',
#  'পুলিশ আশা না দল দালা জনগন জানমাল লুণ্ঠন',
#  'সর্বস্তরে চোর ডাকাত কবলে বাংলাদেশ জিম্মি হয়ে আল্লাহ রক্ষা কারি নাই কল্পনা পরে ঢাকা টু দুবা হাজা টাকা ওয়ান সাইড টিকিট অথচ করোনা কালে পাকিস্তান ভারত টিকিট মূল্য বাংল হাজা টাকা মগ মুল্লু বসবাস কর দেখ নাই',
#  'ব্রাজিল স্বাস্থ্য সেবা ভেঙ্গে পড় রিপোর্ট করছেনঅ অামা স্বাস্থ্য সেবা খুব শক্ত অবস্থানে অাছ নাযত হলুদ সাংবাদিকতা অাপনা করছ',
#  'সময় টিভির সাংবাদিক হাত দড়ি বেঁধে দেয়া মুখে কসটেপ অথবা সুপ গ্লু লাগিয়ে দেয়া আজেবাজে নিউজ প্রচ না',
#  'কোয়ারেন্টাইন না মান যুক্তি দেখাব বা পাওয়ায় দেখানোর চেষ্ কর গরম ডিম যথাস্থানে জাহাজে সমুদ্র মাঝখানে দিন আসা',
#  'আজব কিছুতে বিদেশী উদাহারণ দেশ পরিচালন স্বার্থে বিদেশী সিস্টেম মান চল পারিনা',
#  'বাধা দেয় অশিক্ষিত কুশিক্ষত মূর্খ বিচার আওতায় আনা উচিৎ',
#  'স্বাস্থ্যবিধি মানা সরক জোরালো আইন',
#  'দেখ বিভিন্ন দেশ ভ্যাকসিন নেয় ফলে পার্শ্ব প্রতিক্রিয়া মারা ভ্যাকসিন নেয় জন্য কিনা সেটা নিশ্চিত পারেনি তারপর গণমাধ্যমে অথবা ফেসবু বিভিন্ন খবরে এই আসছেএজন্য মাঝে ভীতি ছড়',
#  'ভাবমূর্তি পাগল ছাগল',
#  'ভালো ঘন্ শপিংমল খোলা রাখ বুঝবে মজা হুশ জ্ঞান এখনো আস না',
#  'শিক্ষা মন্ত্রণালয় ব্যর্থতা এভাবে সরকার ব্যর্থতায় পর্যবসিত হয়',
#  'সরক স্কুল মাদ্রাসা র প্রনোদনা দরক সরক দুর্নীতি',
#  'লাশ এলাকায় ঢুক দেয় নি ঈদ ঢাকা ঢুক দেয়',
#  'পুলিশ নিজেরা আইন মানে মা ঘুষ খায় তাড়া কঠোর হাস্যকর কথা বাংলাদেশের পুলিশ কারনে আসামি আরামে নাক তেল ঘুমায়',
#  'কড়াকড়ি আরোপ',
#  'আচ্ছা ত্রান চুরি চোর গুলো শুয়োর বাচ্চা তাইলে আমায় গালি দিবে',
#  'বাংলাদেশ লাভ নেই সরক এদের মূল্যায়ন না',
#  'সরক বাজেট করেনাজুয়ারি জুয়া খেল সরক বাজেট',
#  'অবাক সমস্ত রিপোর্ট একবছর করোনাভাইরাস বাংলাদেশ তারপর কিভাবে আইসিউ সংকট হয় লজ্জা হয় না',
#  'মত ডাকাত চালু করলে সমস্যা নেই বন্ধ থাকলে সমস্যা নাই বুজবি মরলে চোরকত প্রক',
#  'বাংলাদেশের কোথা করোনা নাই ভন্ডামী',
#  'স্বাস্থ্যবিধি না মানলে জাল বন্দি রাখ না পুলিশ ঘোর গাস',
#  'চীন বেশি বাড় গেছেচীন বিচ দরকারদেরি বড় ধরণ সমস্যা',
#  'পুলিশ বেশি আশা ঠিক না এই মত হলে কর্মকাণ্ড পশুর চায় নিকৃষ্ট সময় এস এদের পরিব সামাজিক বয়কট',
#  'বাংলাদেশের পুলিশ বড় ডাকাত হারাম খোর রাত অন্ধকারে পতি গাড়ি টাকা দূর পাল্ল বাস সার্ভ দেয়',
#  'গণপরিবহন বন্ধ শপিংমল খোলা উড়ে উড়ে শপিং আজাইরা',
#  'অড়া শরম ন লাগে এসব প্রচ গইত্তে কিছুদিন খুব চাপাবাজি মারতি দেশ সিংগাপুর মালেশিয় সমপর্য গেছেএ বুঝি উন্নয়ন',
#  'কথায় কথায় কমি গঠন যেদিন কমি গঠন এদেশ বিতাড়িত সেইদিন সোন বাংলা',
#  'দেশ এখোন মারকেটিং কোমপানি বাজারে বিড়ি সিগারেট বিক্রয় জন্নো এসআর পাঠ পোশাশন আকুল আবেদন আপনা এগুলা বন্দো',
#  'মরে ভ্যাক্সিন নিবো না',
#  'দেখ বিভিন্ন দেশ ভ্যাকসিন নেয় ফলে পার্শ্ব প্রতিক্রিয়া মারা ভ্যাকসিন নেয় জন্য কিনা সেটা নিশ্চিত পারেনি তারপর গণমাধ্যমে অথবা ফেসবু বিভিন্ন খবরে এই আসছেএজন্য মাঝে ভীতি ছড়',
#  'করোন ভুয়া রিপোর্ট ডাক্তার ব্যবসা ছাড়া নেই লকডাউন',
#  'স্যালাইন পানি ভরে টিকা বানা হরদম মানু বোকা বান',
#  'বাঙা বাংলাদেশি হয় অপপ্রচ হেসেছেন ব্যঙ্গ হাসিতা গালে জুতা মার ★ বায়োটেকের জন্ম ইউরোপে হওয়া ছিলো বাঙা বাংলাদেশি নাগরিক হিসাবে গর্ব বোধ কর ★★এখন অনেক নামক চাটুক তেলবাজ বায়োটেকের লেবেল লাগা বড় বড় কথা বলবে',
#  'মাক্স না পড়লে শাস্তি দেয়া অযথা করোনা টেস্ট সরক অর্থ নষ্ট বুঝি না',
#  'না রিকশা ভাঙচুর টিকম',
#  'দেশ সরাসরি হত্যা দেশ বাচানোর লকডাউন দেয়া হাস্যকর',
#  'লকডাউন জোরদ',
#  'করোনা পুঁজি ব্যাবসায় নাম বল চুরি খেয়ে পার',
#  'সমস্ত অমানুষ জায়গায় অনেক জায়গায় প্রভাব বিস্ত অনেক জায়গায় না আসলে কতটুকু সভ্য সমাজে বাস করোনা ভাইরাস আবির্ভাব ভাল অনুধাবন পেরেছি মরনশীল হীন কাজ কর আল্লাহ না আত্নীয় করোনায় আক্রান্ত মার পারত',
#  'সরক ইচ্ছা দেশ করোনা ছড়',
#  'বাংলাদেশ কয় সংবাদ মাধ্যম দালালে পরিনত হয়েছেআম হতভাগা এই বিশ্বাস',
#  'কিস জরিমানা পুলিশ পেট মোটা হলোএমনেত জনগন মার খায় সরক হুকুম গরিব মাট লাথি মারে খাবে',
#  'সরকার আসকা পায় জানোয়',
#  'প্রথম প্রথম অনেক পাকি ভারতীয় বাংলাদেশী দালাল হাস্যরসে মুখরিত ছিলো বহুদিন মোক্ষম জবাব দিল',
#  'বাংলাদেশের আইন বলে কথামিনিটে মিনিটে পরিবর্তন গরীব সাধারণ কথা চিন্তা খোলে',
#  'আকিজ গ্রুপ হাসপাতাল এলাকায় দেয়া হয়নি অই এল জদি করনা আক্রান্ত চিকিৎসা না দেয়া',
#  'হাসপাতাল অপারেশন টাইমে লক্ষ লক্ষ টাকা নে মহামারী টাইমে টাকা কোথায় এভাবে অসহায় মতন রাস্তায় রাস্তায় ঘুর',
#  'শিক্ষা প্রতিষ্ঠান খোল কথা শুনলে করোনাভাইরাস বেড়ে সার গণহারে গণসংযোগ করুণা বারে না ভিনদেশি কান বাংলাদেশের বিভিন্ন অনুষ্ঠান করানো হয় করুণা কোথায়',
#  'সিংগাপুর কানা উন্ন অবস্থাপ্রধানমন্ত্রী তার ছাল লুটপাট দেশ শেষ করল',
#  'লকডাউন দিলে ভালো এসব আবাল মারকা লকডাউন লাভ খোলা লকডাউন ফাজলামুর সীমা দরক',
#  'জনঅকল্যাণকর সংবাদমাধ্যম',
#  'এগুলা আজাইরা পেঁচাল বাদ শিক্ষা প্রতিষ্ঠান কবে খুলবে সেটা বলেনআর খোল নিউজ তৈরি',
#  'কেমন লকডাউন সেখান চলা ফের এখনো',
#  'দেশ লকডাউন গন্ধ নাইসেখানে এখনো হাজা মৃত্যু হয়নিআর নিউজ কত লাখ মৃত্যু',
#  'লজ্জা হওয়া',
#  'জনগন হয়রানি বন্ধ করা',
#  'লকডাউন অসচেতন মানুষ করোনায় মর',
#  'অমানবিক প্রশাসন অদক্ষত পরিচয়',
#  'কুত্ত বাচ্চা পরীক্ষ সংখ্যা উল্লেখ করপরীক্ষা বাড়লে শনাক্তকরন কমবে',
#  ...]

# %% [markdown]
# #  TF-IDF(term frequency-inverse document frequency)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(use_idf=True,tokenizer=lambda x: x.split())
X = cv.fit_transform(corpus).toarray()
y = df_upsampled.as_matrix(["Category"])
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.

# %%
cv.get_feature_names()
# Out:
# ['"',
#  "'",
#  '|',
#  '||',
#  '|||||',
#  '|আমা',
#  'অ',
#  'অ_সুরক্ষিত',
#  'অংক',
#  'অংশ',
#  'অংশগ্রহন',
#  'অংশিদ',
#  'অকারণে',
#  'অকার্য্যকর',
#  'অকাল',
#  'অকৃতজ্ঞ',
#  'অক্রিজ',
#  'অক্সফোর্ড',
#  'অক্সিজ',
#  'অক্সিজেনের',
#  'অগ্রগতি',
#  'অগ্রাধিক',
#  'অগ্রিম',
#  'অচিরে',
#  'অচেনা',
#  'অজান্',
#  'অজুহাত',
#  'অঞ্চল',
#  'অঞ্চলসহ',
#  'অটো',
#  'অটোরিকশায়',
#  'অটোরিক্স',
#  'অত',
#  'অতএব',
#  'অতন্ত্য',
#  'অতি',
#  'অতিক্রম',
#  'অতিদ্রুত',
#  'অতিরিক্ত',
#  'অতিষ্ট',
#  'অতিষ্ঠ',
#  'অতিসত্বর',
#  'অতীব',
#  'অত্য',
#  'অত্যন্ত',
#  'অত্যাচারী',
#  'অত্যান্ত',
#  'অথচ',
#  'অথচো',
#  'অথবা',
#  'অদক্ষ',
#  'অদক্ষত',
#  'অদক্ষতা',
#  'অদূরদর্শীতা',
#  'অদৃশ্য',
#  'অধঃপতন',
#  'অধিক',
#  'অধিকাংশ',
#  'অধিদপ্তর',
#  'অধিবাসিকিন্তুু',
#  'অন',
#  'অনতিবিলম্বে',
#  'অনন্য',
#  'অনলাইন',
#  'অনলাইনে',
#  'অনাগ্রহী',
#  'অনাদ',
#  'অনাহারে',
#  'অনিদিষ্ট',
#  'অনিবার্য',
#  'অনিয়ম',
#  'অনিশ্চিত',
#  'অনিশ্চয়তা',
#  'অনীহা',
#  'অনুচিত',
#  'অনুদান',
#  'অনুধাবন',
#  'অনুপ্রবেশ',
#  'অনুভব',
#  'অনুমতি',
#  'অনুমতির',
#  'অনুমদন',
#  'অনুমোদন',
#  'অনুমোদনগরীব',
#  'অনুমোধন',
#  'অনুযায়ী',
#  'অনুরাগী',
#  'অনুরোধ',
#  'অনুরোধ',
#  'অনুরোধদেশীয়',
#  'অনুষ্ঠান',
#  'অনুসারে',
#  'অনূমোদন',
#  'অনে',
#  'অনেক',
#  'অনেককতোদিন',
#  'অনেককে',
#  'অনেকদিন',
#  'অনেকবড়',
#  'অনেকেইনারায়ণগঞ্জ',
#  'অনেকের',
#  'অনেরা',
#  'অনৈতিক',
#  'অন্তত',
#  'অন্ততপক্ষে',
#  'অন্তর',
#  'অন্তরভূক্ত',
#  'অন্তরে',
#  'অন্তস্তল',
#  'অন্তস্থল',
#  'অন্তোত',
#  'অন্ধ',
#  'অন্ধক',
#  'অন্ন',
#  'অন্য',
#  'অন্যকিছু',
#  'অন্যকে',
#  'অন্যকোন',
#  'অন্যতম',
#  'অন্যত্র',
#  'অন্যথায়',
#  'অন্যথায়',
#  'অন্যদি',
#  'অন্যদেশের',
#  'অন্যভাবে',
#  'অন্যরা',
#  'অন্যরে',
#  'অন্যান্য',
#  'অন্যায়',
#  'অন্যে',
#  'অন\u200d্য',
#  'অপকর্মকান্ড',
#  'অপকৌশল',
#  'অপচেষ্',
#  'অপছন্',
#  'অপছন্দ',
#  'অপদার্থ',
#  'অপপ্রচ',
#  'অপপ্রচার',
#  'অপব্যবহ',
#  'অপব্যাবহারকারী',
#  'অপমান',
#  'অপর',
#  'অপরদি',
#  'অপরাধ',
#  'অপরাধী',
#  'অপরাধে',
#  'অপর্যাপ্ততা',
#  'অপারগতা',
#  'অপারেটর',
#  'অপারেশন',
#  'অপুষ্টিকর',
#  'অপেক্ষ',
#  'অপেক্ষা',
#  'অপেক্ষায়',
#  'অপেক্ষারত',
#  'অপেক্ষায়',
#  'অপেশ',
#  'অপ্রতুল',
#  'অপ্রত্যাশিত',
#  'অপ্রাপ্তবয়স্ক',
#  'অপ্রিয়',
#  'অপ্রয়োজন',
#  'অপ্রয়োজনীয়',
#  'অফ',
#  'অফিস',
#  'অফিসে',
#  'অবকাশ',
#  'অবগত',
#  'অবগতির',
#  'অবদান',
#  'অবলম্বন',
#  'অবশ্য',
#  'অবস্তা',
#  'অবস্থ',
#  'অবস্থা',
#  'অবস্থাআব',
#  'অবস্থান',
#  'অবস্থানে',
#  'অবস্থাপ্রধানমন্ত্রী',
#  'অবস্থাব্যবস্থা',
#  'অবস্থায়',
#  'অবস্থায়',
#  'অবস্হা',
#  'অবস্হান',
#  'অবস্হায়',
#  'অবহেল',
#  'অবহেলা',
#  'অবহেলিত',
#  'অবাক',
#  'অবাগ',
#  'অবাধ',
#  'অবাধ্য',
#  'অবিচ',
#  'অবিমত',
#  'অবিরাম',
#  'অবিশ্বাস্য',
#  'অবেস্তা',
#  'অবৈধ',
#  'অব্যবস্থাপন',
#  'অব্যাবস্থাপনা',
#  'অব্যাবস্হাপনা',
#  'অভভাবক',
#  'অভাগা',
#  'অভাব',
#  'অভাবজ্ঞান',
#  'অভাবে',
#  'অভাবেনিরহ',
#  'অভিচ',
#  'অভিজ্ঞতা',
#  'অভিনন্দন',
#  'অভিভাবক',
#  'অভিযানে',
#  'অভিযুক্ত',
#  'অভিযো',
#  'অভিযোগ',
#  'অভিশপত',
#  'অভিশাপ',
#  'অভুক্ত',
#  'অভ্যস্ত',
#  'অভ্যাস',
#  'অমঙ্গল',
#  'অমানবিক',
#  'অমানবিকতা',
#  'অমানুষ',
#  'অমানুষগীরি',
#  'অমানুষে',
#  'অমানুসি',
#  'অমান্য',
#  'অমুক',
#  'অযথা',
#  'অযুহাততা',
#  'অযোগ্য',
#  'অর্জন',
#  'অর্থ',
#  'অর্থনিতির',
#  'অর্থনীতি',
#  'অর্থনীতির',
#  'অর্থনীতিশিল্পখাত',
#  'অর্থনৈতিক',
#  'অর্থাৎ',
#  'অর্ধেক',
#  'অলরেডি',
#  'অলিগলি',
#  'অলিগলির',
#  'অল্প',
#  'অশনিসংকেত',
#  'অশিক্ষিত',
#  'অষ্টেলিয়',
#  'অসংখ্য',
#  'অসচেতন',
#  'অসচেতনএখন',
#  'অসচেতনতা',
#  'অসচেতনতাতবে',
#  'অসচেতনা',
#  'অসততা',
#  'অসত্য',
#  'অসন্তোষজনক',
#  'অসভ্য',
#  'অসভ্যতা',
#  'অসম্ভব',
#  'অসহনীয়',
#  'অসহায়',
#  'অসহায়',
#  'অসাদু',
#  'অসাবধানত',
#  'অসাড়তা',
#  'অসুখ',
#  'অসুখে',
#  'অসুবিধা',
#  'অসুবিধায়',
#  'অসুস্থ',
#  'অসুস্থতা',
#  'অসূয়া',
#  'অস্কিজ',
#  'অস্তিত্ব',
#  'অস্থিরতা',
#  'অহংক',
#  'অাগামী',
#  'অাগে',
#  'অাগেইভারত',
#  'অাছ',
#  'অাছেএকদি',
#  'অাজিবন',
#  'অাতঙ্কিতভয়',
#  'অাপনা',
#  'অামদানি',
#  'অামা',
#  'অাম্লীক',
#  'অার',
#  'অারামে',
#  'অাল্লাহ',
#  'অাশা',
#  'অ্যাকশনে',
#  'অ্যাভিগগ',
#  'অড়া',
#  "আ'লীগ",
#  'আই',
#  'আইডি',
#  'আইতে',
#  'আইন',
#  'আইনযত',
#  'আইনশৃঙ্খলা',
#  'আইনানুগ',
#  'আইনি',
#  'আইভ',
#  'আইসিইউ',
#  'আইসিইউতে',
#  'আইসিউ',
#  'আইসোলসনে',
#  'আইসোলেশন',
#  'আইসোলেশনে',
#  'আউট',
#  'আউরাবে',
#  'আওটকে',
#  'আওতা',
#  'আওতাধীন',
#  'আওতায়',
#  'আওতায়',
#  'আওয়ামী',
#  'আওয়াজ',
#  'আওয়াতায়',
#  'আওয়ামী',
#  'আক',
#  'আকব',
#  'আকর্ষণ',
#  'আকর্ষন',
#  'আকার',
#  'আকারে',
#  'আকাল',
#  'আকাশ',
#  'আকাশচুম্বী',
#  'আকিজ',
#  'আকুতি',
#  'আকুল',
#  'আক্কেল',
#  'আক্রমণ',
#  'আক্রমন',
#  'আক্রান্ত',
#  'আখেরাতেআর',
#  'আগ',
#  'আগমনবহির্গমন',
#  'আগান',
#  'আগামি',
#  'আগুন',
#  'আগে',
#  'আগেপরে',
#  'আগ্রহ',
#  'আগ্রহী',
#  'আঙ্গুল',
#  'আচরণ',
#  'আচুদা',
#  'আচ্ছা',
#  'আছ',
#  'আছরন',
#  'আছিআর',
#  'আছিকিভাবে',
#  'আছিদয়া',
#  'আছি…',
#  'আছেআছে',
#  'আছেআম',
#  'আছেকাজে',
#  'আছেতা',
#  'আছেনবিওশালী',
#  'আছেবেশী',
#  'আছেসরক',
#  'আছেসাধারণ',
#  'আজ',
#  'আজক',
#  'আজগবী',
#  'আজব',
#  'আজরাইল',
#  'আজাইরা',
#  'আজাব',
#  'আজারিইয়া',
#  'আজেবাজে',
#  'আজোলোকেরা',
#  'আট',
#  'আটক',
#  'আটকা',
#  'আটকানো',
#  'আটকাবে',
#  'আটাকা',
#  'আড়াইশো',
#  'আড়ালে',
#  'আতং',
#  'আতংক',
#  'আতংকিত',
#  'আতঙ্ক',
#  'আতঙ্কবলা',
#  'আতঙ্কিত',
#  'আত্নঘাতি',
#  'আত্নীয়',
#  'আত্বঘাতী',
#  'আত্বীসজন',
#  'আত্মঘাতী',
#  'আত্মরক্ষা',
#  'আত্মসম্মান',
#  'আত্মসাৎ',
#  'আত্মহত্যা',
#  'আত্মহত্যায়',
#  'আত্মা',
#  'আত্মীয়',
#  'আত্মীয়',
#  'আদর',
#  'আদা',
#  'আদায়',
#  'আদাল',
#  'আদালত',
#  'আদায়',
#  'আদেশ',
#  'আদৌ',
#  'আদ্য',
#  'আধম',
#  'আধা',
#  'আধাঘণ্',
#  'আধুনিক',
#  'আধুনিকায়ন',
#  'আন',
#  'আনন্দ',
#  'আনন্দে',
#  'আনবে',
#  'আনবো',
#  'আনলে',
#  'আনা',
#  'আনাহ',
#  'আনিয়া',
#  'আনেক',
#  'আনেদালন',
#  'আন্',
#  'আন্তঃ',
#  'আন্তঃজেলা',
#  'আন্তঃনগর',
#  'আন্তজেলা',
#  'আন্তরিক',
#  'আন্তরিকতা',
#  'আন্তরিকভাবে',
#  'আন্তর্জাতিক',
#  'আন্দাজ',
#  'আন্দোলন',
#  'আন্দোলনে',
#  'আপন',
#  'আপনজন',
#  'আপনা',
#  'আপনাকে',
#  'আপনাগো',
#  'আপনাদেরকে',
#  'আপনারা',
#  'আপনি',
#  'আপনে',
#  'আপসেট',
#  'আপসোস',
#  'আপাতত',
#  'আপিল',
#  'আপু',
#  'আপুআল্লাহ',
#  'আপ্ন',
#  'আফসোস',
#  'আফা',
#  'আফ্রিকান',
#  'আব',
#  'আবদ',
#  'আবদ্ধ',
#  'আবস্থা',
#  'আবহাওয়',
#  'আবাইল্যা',
#  'আবারতার',
#  'আবারো',
#  'আবাল',
#  'আবাসিক',
#  'আবির্ভাব',
#  'আবিষ্ক',
#  'আবিষ্কৃত',
#  'আবিস্ক',
#  'আবুধাবি',
#  'আবুল',
#  'আবেগ',
#  'আবেদন',
#  'আব্ব',
#  'আভাস',
#  'আম',
#  'আমজন',
#  'আমজনত',
#  'আমজনতা',
#  'আমদানি',
#  'আমদানির',
#  'আমদানী',
#  'আমরা',
#  'আমরাআল্লাহ',
#  'আমরাপা',
#  'আমল',
#  'আমলা',
#  'আমলে',
#  'আমা',
#  'আমাদেরইআমাদের',
#  'আমানুষ',
#  'আমায়',
#  'আমি',
#  'আমিন',
#  'আমিনসচেনতা',
#  'আমীন',
#  'আমেরিকা',
#  'আমেরিকাচিনযুক্তরাষ্ট্রইতালিপ্রায়',
#  'আমেরিকান',
#  'আমেরিকার',
#  'আমেরিকারে',
#  'আমেরীকা',
#  'আয়',
#  'আয়তন',
#  'আয়োজন',
#  'আর',
#  'আরকি',
#  'আরব',
#  'আরবে',
#  'আরম্ভ',
#  'আরশ',
#  'আরসরকারপবাসি',
#  'আরসহ্য',
#  'আরাম',
#  'আরামে',
#  'আরেক',
#  'আরেকজন',
#  'আরেকদি',
#  'আরোপ',
#  'আর্জি',
#  'আর্তনাদ',
#  'আর্থনিতির',
#  'আর্থিক',
#  'আর্ধেক',
#  'আর\u200d',
#  'আললাহ',
#  'আললাহর',
#  'আলহামদুলিল্লাহ',
#  'আলহামদুলিল্লাহ্',
#  'আলা',
#  'আলাদা',
#  'আলামত',
#  'আলামিন',
#  'আলামিনের',
#  'আলেম',
#  'আলো',
#  'আলোকিত',
#  'আলোচনা',
#  'আলোর',
#  'আল্ল',
#  'আল্লা',
#  'আল্লায়',
#  'আল্লাহ',
#  'আল্লাহত',
#  'আল্লাহতালা',
#  'আল্লাহপাক',
#  'আল্লাহর',
#  'আল্লাহরউপর',
#  'আল্লাহু',
#  'আল্লাহ্',
#  'আল্লাহ্\u200c',
#  'আশ',
#  'আশংকাজনক',
#  'আশঙ্কা',
#  'আশা',
#  'আশাক',
#  'আশাকরি',
#  'আশায়',
#  'আশেপাশে',
#  'আশ্চর্য',
#  'আস',
#  'আসকা',
#  'আসছ',
#  'আসছিল',
#  'আসছেআমা',
#  'আসছেনা',
#  'আসত',
#  'আসতা',
#  'আসতাছ',
#  'আসতেআমি',
#  'আসতেচ',
#  'আসতেছেনা',
#  'আসন',
#  'আসনে',
#  'আসন্ন',
#  'আসবে',
#  'আসবেনা',
#  'আসবেসব',
#  'আসল',
#  'আসলে',
#  'আসলো',
#  'আসহায়',
#  'আসা',
#  'আসামি',
#  'আসাযাওয়া',
#  'আসায়',
#  'আসি',
#  'আসিআবুধাবি',
#  'আসিফ',
#  'আসুক',
#  'আসুন',
#  'আসো',
#  'আস্',
#  'আস্তা',
#  'আস্থ',
#  'আস্থা',
#  'আস্হা',
#  'আহবান',
#  'আহরে',
#  'আহহারে',
#  'আহা',
#  'আহাজারি',
#  'আহারে',
#  'আহ্বান',
#  'আহ্মেদ',
#  'আাঘাত',
#  'আাদায়কারী',
#  'আ্ল্লাহ',
#  'আয়',
#  'আয়ু',
#  'আয়োজন',
#  'আ\u200cসে',
#  'ইংলিশ',
#  'ইউ',
#  'ইউনিট',
#  'ইউনিটে',
#  'ইউনিফর্ম',
#  'ইউনিয়ন',
#  'ইউপি',
#  'ইউমিনিটিতে',
#  'ইউমেনি',
#  'ইউরোপ',
#  'ইউরোপে',
#  'ইখতিয়',
#  'ইচ্',
#  'ইচ্ছা',
#  'ইচ্ছাকৃত',
#  'ইচ্ছায়',
#  'ইজ',
#  'ইটপাথর',
#  'ইটা',
#  'ইতা',
#  'ইতালিতে',
#  'ইতালির',
#  'ইতালী',
#  'ইতিমধ্যে',
#  'ইতিমধ্যেই',
#  'ইতিহাস',
#  'ইত্যাদি',
#  'ইদুর',
#  'ইনকাম',
#  'ইনশা',
#  'ইনশাআল্লাহ',
#  'ইনশাল্লাহ',
#  'ইনাদেরকে',
#  'ইনিতো',
#  'ইন্চি',
#  'ইন্টারনেটে',
#  'ইন্ডাস্ট্র',
#  'ইন্ডিইয়',
#  'ইন্ডিয়',
#  'ইন্ডিয়',
#  'ইন্ডিয়া',
#  'ইন্ডিয়াতেই',
#  'ইন্ডিয়ান',
#  'ইন্ডিয়ায়',
#  'ইন্দন',
#  'ইফতার',
#  'ইবাদত',
#  'ইবোলাএই',
#  'ইভাবে',
#  'ইমান',
#  'ইমার্জেন্সি',
#  'ইমিউইনি',
#  'ইমিউনি',
#  'ইমিনিউ',
#  'ইমুউনি',
#  'ইমেজ',
#  'ইমোশন',
#  'ইম্যুনি',
#  'ইস',
#  'ইসলামের',
#  'ইস্কুল',
#  'ইস্টাইল',
#  'ইস্যু',
#  'ইয়',
#  'ইয়া',
#  'ঈদ',
#  'ঈদে',
#  'ঈদের',
#  'উওর',
#  'উকিল',
#  'উক্ত',
#  'উচিতআচমকা',
#  'উচিতআল্লাহ',
#  'উচিতএ',
#  'উচিতচাুউলতেলটাকা',
#  'উচিততা',
#  'উচিতনতুবা',
#  'উচিতযা',
#  'উচিদভা',
#  'উচিৎ',
#  'উচিৎবলে',
#  'উচ্চ',
#  'উচ্চতায়',
#  'উছিলা',
#  'উছিলায়',
#  'উজ্জুক',
#  'উজ্জ্বল',
#  'উট',
#  'উটাইয়া',
#  'উঠ',
#  'উঠত',
#  'উঠবে',
#  'উঠবো',
#  'উঠলো',
#  'উঠা',
#  'উঠানোর',
#  'উঠাবে',
#  'উঠালে',
#  'উঠিয়ে',
#  'উঠে',
#  'উতসাহ',
#  'উত্তম',
#  'উত্তর',
#  'উত্তরণে',
#  'উত্তির্ন',
#  'উত্তোলন',
#  'উদযাপন',
#  'উদাম',
#  'উদাসীন',
#  'উদাসীনত',
#  'উদাসীনতা',
#  'উদাসীনতায়',
#  'উদাহারণ',
#  'উদ্দেশ্য',
#  'উদ্দেশ্যে',
#  'উদ্দোগ',
#  'উদ্দৌগে',
#  'উদ্ধ',
#  'উদ্বিগ্ন',
#  'উদ্বুদ্ধ',
#  'উদ্বেগ',
#  'উদ্বেগজনক',
#  'উদ্বোধন',
#  'উদ্ভাবনী',
#  'উদ্যোগ',
#  'উদ্যোক্তা',
#  'উদ্যোগ',
#  'উদ্যোগসা',
#  'উদ্যোগে',
#  'উন',
#  'উনা',
#  'উন্ন',
#  'উন্নত',
#  'উন্নতি',
#  'উন্নয়ন',
#  'উন্নয়ন',
#  'উন্নয়নশীল',
#  'উন্মুক্ত',
#  'উপ',
#  'উপক',
#  'উপকার',
#  'উপকারী',
#  'উপকারে',
#  'উপকৃত',
#  'উপক্রিত',
#  'উপজেলা',
#  'উপজেলায়',
#  'উপদেশ',
#  'উপভোগ',
#  'উপযোগী',
#  'উপর',
#  'উপরধান্দা',
#  'উপরেনাম',
#  'উপলক্ষে',
#  'উপলব্দি',
#  'উপলব্ধি',
#  'উপসর্গ',
#  'উপস্থাপন',
#  'উপস্থাপনা',
#  'উপস্থিতি',
#  'উপহ',
#  'উপহাস',
#  'উপাদান',
#  'উপায়',
#  'উপায়ে',
#  'উপারজন',
#  'উপার্জন',
#  'উপায়',
#  'উপেক্ষা',
#  'উপড়',
#  'উম্মক্ত',
#  'উম্মাহর',
#  'উম্মুক্ত',
#  'উযুকি',
#  'উরাধোরা',
#  'উর্ধ্বতন',
#  'উর্পাজন',
#  'উলজ্ঞ',
#  'উলোবনে',
#  'উল্',
#  'উল্টাইয়া',
#  'উল্টো',
#  'উল্লেখ',
#  'উল্লেখযোগ্য',
#  'উসিলা',
#  'উসিলায়',
#  'উসুল',
#  'উৎকর্ষ',
#  'উৎকৃষ্ট',
#  'উৎপাদন',
#  'উৎপাদনে',
#  'উৎপাদিত',
#  'উৎসব',
#  'উৎসাহ',
#  'উৎসাহিত',
#  'উড়া',
#  'উড়ে',
#  'ঊর্ধ্বে',
#  'ঋণ',
#  'ঋন',
#  'এই',
#  'এইকুকুর',
#  'এইগুলোও',
#  'এইজন্য',
#  'এইডানদিয়া',
#  'এইব',
#  'এইভাবে',
#  'এইভাবেই',
#  'এইমূহূর্তে',
#  'এইসব',
#  'এই\u200c',
#  'এক',
#  'একইরকম',
#  'একইসাথে',
#  'একএক',
#  'একজনে',
#  'একটু',
#  'একত্রিত',
#  'একত্রে',
#  'একদম',
#  'একদল',
#  'একদি',
#  'একদিন',
#  'একদিনে',
#  'একধরন',
#  'একন',
#  'একপ্রক',
#  'একবছর',
#  'একবারে',
#  'একবারো',
#  'একবেল',
#  'একমাত্র',
#  'একমাত্র্',
#  'একমাস',
#  'একমাসেররেমিট্যানস',
#  'একমি',
#  'একমুখী',
#  'একলাখ',
#  'একশ',
#  'একসঙ্গে',
#  'একসময়',
#  'একসাথে',
#  'একা',
#  'একাউন্ট',
#  'একাউন্টে',
#  'একান্ত',
#  'একি',
#  'একে',
#  'একেক',
#  'একেবারে',
#  'এক্সরে',
#  'এক্সাম',
#  'এক্সিডেন্ট',
#  'এখ',
#  'এখন',
#  'এখনব্যবসা',
#  'এখনি',
#  'এখনো',
#  'এখান',
#  'এখোন',
#  'এগা',
#  'এগারো',
#  'এগিয়ে',
#  'এগুলা',
#  'এগুলোরে',
#  'এগোচ্',
#  'এজন্য',
#  'এটা',
#  'এটাখুব',
#  'এটামানবতা',
#  'এটি',
#  'এটিএম',
#  'এটুকু',
#  'এটেন্ড',
#  'এডভান্স',
#  'এডমিশন',
#  'এত',
#  'এতকিছুর',
#  'এতটুকু',
#  'এতদিন',
#  'এতদিনে',
#  'এতদূর',
#  'এতসব',
#  'এতে',
#  'এতেকরেআবিষ্কারক',
#  'এতো',
#  'এতৈ',
#  'এতো',
#  'এতোকিছু',
#  'এতোদিন',
#  'এতোদিনে',
#  'এত্ত',
#  'এদি',
#  'এদিক',
#  'এদিকটায়',
#  'এদিন',
#  'এদের',
#  'এদেশ',
#  'এদেশের',
#  'এধরন',
#  'এধরনে',
#  'এন',
#  'এনজি',
#  'এনজিওর',
#  'এনাউন্স',
#  'এনালাইস',
#  'এনে',
#  'এন্ড',
#  'এপে',
#  'এপ্রিলে',
#  'এফ',
#  'এব',
#  'এবংঅন্যান্য',
#  'এবার',
#  'এবারো',
#  'এবেপারে',
#  'এভাবে',
#  'এম',
#  'এমতাবস্থায়',
#  'এমতাবস্থায়',
#  'এমন',
#  'এমনিতে',
#  'এমনে',
#  'এমপি',
#  'এমপিমন্ত্রী',
#  'এমবি',
#  'এমবিবিএস',
#  'এমবির',
#  'এম্নিতে',
#  'এম্বাসি',
#  'এম্বুলেন্স',
#  'এয়ারপোটে',
#  'এর',
#  'এরকম',
#  'এরকমভাবে',
#  'এরচ',
#  'এরফলে',
#  'এরমধ্যে',
#  'এরমাযে',
#  'এরা',
#  'এরিয়া',
#  'এরূপ',
#  'এরে',
#  'এল',
#  'এলাকা',
#  'এলাকাতে',
#  'এলাকাবাসী',
#  'এলাকায়',
#  'এলাকায়',
#  'এলার্জি',
#  'এলেক',
#  'এলোমেলো',
#  'এশিয়ান',
#  'এস',
#  'এসকল',
#  'এসট্রাজেনেকার',
#  'এসপি',
#  'এসপ্রেসো',
#  'এসব',
#  'এসমস্ত',
#  'এসময়',
#  'এসি',
#  'এসির',
#  'এসে',
#  'এসেছিল',
#  'এসেছেতা',
#  'এসেছেন',
#  'এস্পে',
#  'এান',
#  'এ্যড়',
#  'এয়ারপোর্টে',
#  'ঐই',
#  'ঐক্যবদ্ধ',
#  'ঐদিন',
#  'ওইখানে',
#  'ওইগুলোতে',
#  'ওকলেজ',
#  'ওগো',
#  'ওচিত',
#  'ওজর',
#  'ওঠা',
#  'ওঠে',
#  'ওতে',
#  ...]

# %% [markdown]
# # Cross Validation

# %%
#10 fold Cross validation score off LogisticRegression:

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
model=LogisticRegression()
kfold_validation=KFold(10)


import numpy as np
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=kfold_validation)
print(results)
print(np.mean(results))
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [0.70752688 0.65086207 0.64224138 0.79741379 0.77586207 0.70905172
#  0.79956897 0.74784483 0.71551724 0.73275862]
# 0.7278647571375603

# %%
#10 fold Cross validation score off SVM:

from sklearn import svm
from sklearn.model_selection import KFold
model=svm.SVC(kernel='rbf')
kfold_validation=KFold(10)


import numpy as np
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=kfold_validation)
print(results)
print(np.mean(results))
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [0.77419355 0.75       0.71767241 0.84267241 0.85991379 0.78663793
#  0.84051724 0.7887931  0.76293103 0.79956897]
# 0.7922900444938821

# %%
#10 fold Cross validation score off RandomForestClassifier:

from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import KFold
model=RandomForestClassifier(n_estimators=40)
kfold_validation=KFold(10)


import numpy as np
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=kfold_validation)
print(results)
print(np.mean(results))
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [0.7311828  0.71551724 0.67241379 0.8362069  0.78663793 0.74137931
#  0.7887931  0.82112069 0.76293103 0.82758621]
# 0.7683769002595476

# %% [markdown]
# # **Train_ Test data split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.20,random_state = 342,stratify = y)

# %% [markdown]
# # ML Models Performance

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logreg_model = LogisticRegression()
logreg_model = logreg_model.fit(x_train,y_train)
y_pred_logreg = logreg_model.predict(x_test)

from sklearn.metrics import classification_report
classification_report(y_test,y_pred_logreg)
print(classification_report(y_test,y_pred_logreg))
Accurcy =(accuracy_score(y_test,y_pred_logreg))
print(Accurcy)
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       310
#            1       0.80      0.85      0.83       309
#            2       0.85      0.83      0.84       310
#
#     accuracy                           0.84       929
#    macro avg       0.84      0.84      0.84       929
# weighted avg       0.84      0.84      0.84       929
#
# 0.8428417653390743

# %% [markdown]
# # Confusion Matrix & ROC Curve Visualization of LogisticRegression

# %%
from sklearn.metrics import confusion_matrix
lg_matrix=confusion_matrix(y_test,y_pred_logreg)
print(lg_matrix)

import seaborn as sns
ax = plt.subplot()
sns.set(font_scale=3.0) #edited as suggested
print(sns.heatmap(lg_matrix, annot=True, ax=ax, cmap="Blues", fmt="g")) # annot=True to annotate cells
# Out:
# [[262  28  20]
#  [ 22 263  24]
#  [ 17  36 257]]
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting normalize=True.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cnf_matrix = confusion_matrix(y_test, y_pred_logreg)
#np.set_printoptions(precision=2)
#ax = plt.subplot()
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['0', '1', '2'],
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[262  28  20]
#  [ 22 263  24]
#  [ 17  36 257]]

# %%
from sklearn.linear_model import LogisticRegression

#from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

from yellowbrick.classifier import ROCAUC
from yellowbrick.datasets import load_game

# Load multi-class classification dataset
#X, y = load_game()

# Encode the non-numeric columns
#X = OrdinalEncoder().fit_transform(X)
#y = LabelEncoder().fit_transform(y)

# Create the train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=342)

# Instaniate the classification model and visualizer
logreg_model = LogisticRegression()
visualizer = ROCAUC(logreg_model, classes=["Analytical", "Depressed", "Angry"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show() 
#plt.savefig('ROC_Curve_LR_with_balance_data.png')
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
#from sklearn.naive_bayes import MultinomialNB
#mnb = MultinomialNB(alpha=0.001)
#mnb_model = mnb.fit(x_train,y_train)
#y_pred_mnb = mnb_model.predict(x_test)

#print(classification_report(y_test,y_pred_mnb))

# %% [markdown]
# # Svm with RBF  Kernel

# %%
from sklearn import svm
svm_model = svm.SVC(kernel='rbf')
svm_model = svm_model.fit(x_train,y_train)
y_pred_svm_r = svm_model.predict(x_test)

print(classification_report(y_test,y_pred_svm_r))
Accurcy =(accuracy_score(y_test,y_pred_svm_r))
print(Accurcy)
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       310
#            1       0.88      0.89      0.88       309
#            2       0.89      0.87      0.88       310
#
#     accuracy                           0.89       929
#    macro avg       0.89      0.89      0.89       929
# weighted avg       0.89      0.89      0.89       929
#
# 0.8902045209903121

# %% [markdown]
# # Confusion Matrix & ROC Curve Visualization of Svm

# %%
from sklearn.metrics import confusion_matrix
SVM_matrix=confusion_matrix(y_test,y_pred_svm_r)
print(SVM_matrix)

import seaborn as sns
print(sns.heatmap(SVM_matrix, annot=True))
# Out:
# [[283  14  13]
#  [ 16 274  19]
#  [ 17  23 270]]
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting normalize=True.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cnf_matrix = confusion_matrix(y_test, y_pred_svm_r)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['0', '1', '2'],
                      title='Confusion matrix')
# Out:
# Confusion matrix
# [[283  14  13]
#  [ 16 274  19]
#  [ 17  23 270]]

# %%
from sklearn import svm

#from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

from yellowbrick.classifier import ROCAUC
from yellowbrick.datasets import load_game

# Load multi-class classification dataset
#X, y = load_game()

# Encode the non-numeric columns
#X = OrdinalEncoder().fit_transform(X)
#y = LabelEncoder().fit_transform(y)

# Create the train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=342)

# Instaniate the classification model and visualizer
svm_model = svm.SVC(kernel='rbf')
visualizer = ROCAUC(svm_model, classes=["Analytical", "Depressed", "Angry"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show()
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier 
RF = RandomForestClassifier()
RF_model = RF.fit(x_train,y_train)
y_pred_RF = RF_model.predict(x_test)

print(classification_report(y_test,y_pred_RF))
Accurcy =(accuracy_score(y_test,y_pred_RF))
print(Accurcy)
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87       310
#            1       0.84      0.86      0.85       309
#            2       0.82      0.85      0.84       310
#
#     accuracy                           0.85       929
#    macro avg       0.85      0.85      0.85       929
# weighted avg       0.85      0.85      0.85       929
#
# 0.8503767491926802

# %% [markdown]
# # Confusion Matrix & ROC Curve Visualization of RandomForestClassifier

# %%
from sklearn.metrics import confusion_matrix
rbf_matrix=confusion_matrix(y_test,y_pred_RF)
print(rbf_matrix)

import seaborn as sns
print(sns.heatmap(rbf_matrix, annot=True))
# Out:
# [[260  22  28]
#  [ 11 275  23]
#  [ 17  28 265]]
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting normalize=True.
    """
    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cnf_matrix = confusion_matrix(y_test, y_pred_RF)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['0', '1', '2'],
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[260  22  28]
#  [ 11 275  23]
#  [ 17  28 265]]

# %%
from sklearn.ensemble import RandomForestClassifier 

#from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

from yellowbrick.classifier import ROCAUC
from yellowbrick.datasets import load_game

# Load multi-class classification dataset
#X, y = load_game()

# Encode the non-numeric columns
#X = OrdinalEncoder().fit_transform(X)
#y = LabelEncoder().fit_transform(y)

# Create the train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=342)

# Instaniate the classification model and visualizer
RF = RandomForestClassifier(n_estimators=40)
visualizer = ROCAUC(RF, classes=["Analytical", "Depressed", "Angry"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show()
# Out:
# C:\Users\Riyad\Anaconda3\lib\site-packages\yellowbrick\base.py:390: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator.fit(X, y, **kwargs)
